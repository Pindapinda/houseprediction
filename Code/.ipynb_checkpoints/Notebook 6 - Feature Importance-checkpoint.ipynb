# %%
import pandas as pd
import numpy as np
import re
import math
import pickle
import scipy
import matplotlib.pyplot as plt

from sklearn import metrics
from preprocessing import *
from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.model_selection import GridSearchCV
from scipy.cluster import hierarchy as hc

# %%
best = pickle.load(open('nb5_best.p','rb'))
X_train, y_train = pickle.load(open('train.p','rb'))
X_valid, y_valid = pickle.load(open('valid.p','rb'))
X_test, y_test = pickle.load(open('test.p','rb'))

# %%
(np.exp(y_train) > 1e6).sum()
# Out:
# 211

# %% [markdown]
# **Feature Importance**

# %%
# compute and plot the feature importance for all the columns in the dataframe
fi = rf_feat_importance(best, X_train)
fi.plot('cols', 'imp', figsize=(10,6), legend=False);

# %% [markdown]
# **Analysis:** as usual, there are only a handful of columns that really account for the variance in prices we have in our dataset.  Let's inspect the larger values:

# %%
plot_fi(fi[:30]);

# %% [markdown]
# **Analysis:** perhaps not surpisingly, the factors that are driving price appear to be:
#
# 1) the size of the house <br>
# 2) the appraised value <br>
# 3) average income of residents <br>
# 4) house type (could be correlated with size) <br>
# 5) location (postcode, lat & lon)
#
# Some of these are not housing attributes, per se, and aren't really all that interesting because they describe the people who live in the houses rather than the houses themselves.  If you trying to learn about which features are driving house prices, these aren't very helpful.  We'll explore in greater detail later.  For now, let's simplify the model by using only the most relevant information.

# %%
fi[:30]
# Out:
#                                                   cols       imp
# 129                                             volume  0.290949
# 127                                        livingspace  0.229782
# 163               Gemiddelde woningwaarde:x 1 000 euro  0.090701
# 36                                           housetype  0.048947
# 128                                         lotsurface  0.025862
# 154        Gemiddeld inkomen per inwoner :x 1 000 euro  0.023719
# 136                                 yearofconstruction  0.020692
# 1                                                 V1.x  0.020594
# 37                                        housesubtype  0.015704
# 139                    Meest voorkomende postcode:code  0.010858
# 131                                 postcodenummerdeel  0.010642
# 134                                          longitude  0.010490
# 156                 20% personen met hoogste inkomen:%  0.010177
# 133                                           latitude  0.008670
# 153  Gemiddeld inkomen per inkomensontvanger :x 1 0...  0.007898
# 164                       Percentage eengezinswoning:%  0.006358
# 178        Bevolkingsdichtheid:aantal inwoners per km²  0.006320
# 219                                       startElapsed  0.005994
# 204          Afstand tot belangrijk overstapstation:km  0.005475
# 159              20% huishoudens met hoogste inkomen:%  0.004617
# 147                         Scholen binnen 3 km:aantal  0.004613
# 166                                     Koopwoningen:%  0.003266
# 158              40% huishoudens met laagste inkomen:%  0.002971
# 205                                  postcodealphadeel  0.002485
# 177               Gemiddelde huishoudensgrootte:aantal  0.002458
# 2                                                  url  0.002440
# 132                                            address  0.002296
# 203                Afstand tot treinstations totaal:km  0.002291
# 168                     In bezit overige verhuurders:%  0.002214
# 137                                               V1.y  0.002112

# %%
# We'll use an importance of 0.0025 as a threshold for whether or not to retain a column and retrain the model
# using only these columns

to_keep = fi[fi.imp>0.0025].cols

X_train_2 = X_train[to_keep].copy()
X_valid_2 = X_valid[to_keep].copy()

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_2, y_train)
print_score(m, X_train_2, y_train, X_valid_2, y_valid)
# Out:
# [0.09453038668300566, 0.18005294113732437, 0.9607699736747932, 0.859851494656209, 0.865761962383081]

# %% [markdown]
# **Analysis:** Our previous best scores for validation and oob were 0.8566466844028794 and 0.8636396442979561.  Thus you can see our model has improved slightly.  Our r^2 value on the training set has also decreased slightly, indicating that we are now overfitting slightly less to the training data.

# %% [markdown]
# **Feature Importance 2**
#
# now we examine FI for the simplified model.  Since we have likely removed alot of collinear columns, there is likely to be some change in the order of importance.

# %%
# original plot
plot_fi(fi[:23]);

# %%
# new plot  

fi2 = rf_feat_importance(m, X_train_2)
plot_fi(fi2);

# %% [markdown]
# **Analysis:** The order really didn't change all that much, and the relative importances seem more or less the same.  Let's examine now the correlation between these features.

# %% [markdown]
# **Hierarchical Cluster Analysis**

# %%
corr = np.round(scipy.stats.spearmanr(X_train_2).correlation, 4)
corr_condensed = hc.distance.squareform(1-corr)
z = hc.linkage(corr_condensed, method='average')
fig = plt.figure(figsize=(16,10))
dendrogram = hc.dendrogram(z, labels=X_train_2.columns, 
      orientation='left', leaf_font_size=16)
plt.show()

# %% [markdown]
# **Analysis:** A few things jump out.  postcode number part, V1.x and most common postcode are all identical, thus 2 of these 3 can be dropped.  There's also a very high correlation between average income per income recipient and 20% people with highest income, as well as average house worth and 20% households with highest income (confirming what we said earlier).  Livingspace and volume are also highly correlated.  We should drop one and see the effect on r^2.

# %%
m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_2.drop(['postcodenummerdeel','V1.x'],axis=1), y_train)
print_score(m, X_train_2.drop(['postcodenummerdeel','V1.x'],axis=1), y_train, X_valid_2.drop(['postcodenummerdeel','V1.x'],axis=1), y_valid)

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_2.drop(['postcodenummerdeel','Meest voorkomende postcode:code'],axis=1), y_train)
print_score(m, X_train_2.drop(['postcodenummerdeel','Meest voorkomende postcode:code'],axis=1), y_train, X_valid_2.drop(['postcodenummerdeel','Meest voorkomende postcode:code'],axis=1), y_valid)

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_2.drop(['V1.x','Meest voorkomende postcode:code'],axis=1), y_train)
print_score(m, X_train_2.drop(['V1.x','Meest voorkomende postcode:code'],axis=1), y_train, X_valid_2.drop(['V1.x','Meest voorkomende postcode:code'],axis=1), y_valid)

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_2.drop(['livingspace'],axis=1), y_train)
print_score(m, X_train_2.drop(['livingspace'],axis=1), y_train, X_valid_2.drop(['livingspace'],axis=1), y_valid)

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_2.drop(['volume'],axis=1), y_train)
print_score(m, X_train_2.drop(['volume'],axis=1), y_train, X_valid_2.drop(['volume'],axis=1), y_valid)
# Out:
# [0.09512054365447438, 0.18023979667317624, 0.960278615427436, 0.8595604567830384, 0.8658018164572534]
# [0.09446888787645658, 0.17987757659845172, 0.9608210009708784, 0.8601243600623574, 0.8664742361146642]
# [0.09452305261483897, 0.17997431567842231, 0.9607760607021766, 0.8599738679375155, 0.8672521486583346]
# [0.09755671731824644, 0.18599165814645627, 0.9582179170050478, 0.8504539442242262, 0.8599596895674074]
# [0.09889597463155977, 0.18449266002861744, 0.9570628750978017, 0.8528547606188768, 0.8578020641015132]

# %% [markdown]
# **Analysis:** getting ride of the postcode duplicates doesn't seem to really affect r^2 all that much.  The combination of living space and volume was slighty more predictive than one vs. the other, so we'll keep both (for now)

# %%
X_train = X_train.drop(['postcodenummerdeel','Meest voorkomende postcode:code'], axis=1)
X_valid = X_valid.drop(['postcodenummerdeel','Meest voorkomende postcode:code'], axis=1)
X_test = X_test.drop(['postcodenummerdeel','Meest voorkomende postcode:code'], axis=1)

# %% [markdown]
# **Further Feature Removal**
#
# Next we'll find all features that have something to do with the amount of money people make or the value of homes and remove them from the dataset.  I had to translate the features in English in order to do this, but the subset listed below seems fairly comprehensive:
#
# - Aantal inkomensontvangers  :aantal
# - Gemiddeld inkomen per inkomensontvanger :x 1 000 euro
# - Gemiddeld inkomen per inwoner :x 1 000 euro
# - 40% personen met laagste inkomen:%
# - 20% personen met hoogste inkomen:%
# - 40% huishoudens met laagste inkomen:%
# - 20% huishoudens met hoogste inkomen:%
# - Huishoudens met een laag inkomen:%
# - Huish. onder of rond sociaal minimum:%
# - Gemiddelde woningwaarde:x 1 000 euro

# %%
# we had to extract these due to special formatting characters that cannot be seen

to_drop = [col for col in X_train.columns if 'inkomen' in col] + \
[col for col in X_train.columns if 'woningwaarde' in col] + \
[col for col in X_train.columns if 'sociaal' in col]

X_train = X_train.drop(to_drop, axis=1)
X_valid = X_valid.drop(to_drop, axis=1)
X_test = X_test.drop(to_drop, axis=1)

# %% [markdown]
# **Re-training the model and doing Feature Importance yet again...**

# %%
m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train, y_train)
print_score(m, X_train, y_train, X_valid, y_valid)
# Out:
# [0.086661379870002, 0.18603200708150683, 0.9670293939355702, 0.8503890522966984, 0.8594400949342054]

# %%
fi3 = rf_feat_importance(m, X_train)

# %%
plot_fi(fi3[:30]);

# %%
X_train_3 = X_train[fi3[:30].cols.values]
X_valid_3 = X_valid[fi3[:30].cols.values]

corr = np.round(scipy.stats.spearmanr(X_train_3).correlation, 4)
corr_condensed = hc.distance.squareform(1-corr)
z = hc.linkage(corr_condensed, method='average')
fig = plt.figure(figsize=(16,10))
dendrogram = hc.dendrogram(z, labels=X_train_3.columns, 
      orientation='left', leaf_font_size=16)
plt.show()

# %% [markdown]
# **Analysis:** Finally, we are starting to see some more varied features. As with postcode, there are three columns here measuring exactly the same thing.  We should remove 2 of these 3

# %%
# baseline model

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_3, y_train)
print_score(m, X_train_3, y_train, X_valid_3, y_valid)
# Out:
# [0.09213504617585459, 0.1821383659638322, 0.9627329130705266, 0.8565862134195593, 0.8651255351202788]

# %%
m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_3.drop(['buurt_code','wijk_code'], axis=1), y_train)
print_score(m, X_train_3.drop(['buurt_code','wijk_code'], axis=1), y_train, X_valid_3.drop(['buurt_code','wijk_code'], axis=1), y_valid)

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_3.drop(['V1.y','wijk_code'], axis=1), y_train)
print_score(m, X_train_3.drop(['V1.y','wijk_code'], axis=1), y_train, X_valid_3.drop(['V1.y','wijk_code'], axis=1), y_valid)

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_3.drop(['buurt_code','V1.y'], axis=1), y_train)
print_score(m, X_train_3.drop(['buurt_code','V1.y'], axis=1), y_train, X_valid_3.drop(['buurt_code','V1.y'], axis=1), y_valid)
# Out:
# [0.09244603360505763, 0.18264976025508903, 0.9624809100494623, 0.8557797501355229, 0.8643112001829891]
# [0.09236206209732918, 0.18210983318363266, 0.962549038525426, 0.8566311427073999, 0.8648525271792387]
# [0.0920656947428508, 0.18202803289310204, 0.9627889949478131, 0.85675991093549, 0.8655504557350617]

# %% [markdown]
# **Analysis:** We should keep buurt_code

# %%
to_drop = ['wijk_code','V1.y']
X_train = X_train.drop(to_drop, axis=1)
X_valid = X_valid.drop(to_drop, axis=1)
X_test = X_test.drop(to_drop, axis=1)

# %%
m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train, y_train)
print_score(m, X_train, y_train, X_valid, y_valid)
# Out:
# [0.08622109817014609, 0.18556510519953837, 0.9673635561530706, 0.851139094991509, 0.8608228595852091]

# %%
fi4 = rf_feat_importance(m, X_train)

# %%
plot_fi(fi4[:30]);

# %%
X_train_4 = X_train[fi4[:30].cols.values]
X_valid_4 = X_valid[fi4[:30].cols.values]

corr = np.round(scipy.stats.spearmanr(X_train_4).correlation, 4)
corr_condensed = hc.distance.squareform(1-corr)
z = hc.linkage(corr_condensed, method='average')
fig = plt.figure(figsize=(16,10))
dendrogram = hc.dendrogram(z, labels=X_train_4.columns, 
      orientation='left', leaf_font_size=16)
plt.show()

# %% [markdown]
# **Analysis:** What are some clusters we see here?  Going down the list from top to bottom, we observe the following clusters:
#
# - bedrooms and total rooms<br>
# - livingspace and volume<br>
# - longitude and V1.x (postcode) <br>
# - Non-westerners and people with an allowance benefit<br>
# - number of financial services and number of business services<br>
#
# The first and second are housing characteristics, the third is geographical location, the fourth a potential indicator of poverty, and the fifth indicates proximity to busines-heavy areas.  At this point there are two things we can do:
#
# 1) Inspect the categorical features more closely and see if it's possible to either create more features from them, or to eliminate them based on redundancy<br>
# 2) Experiment with dropping the semi-correlated features
#
# Let's start with the first.  For this we'll need to import the dataset from the first notebook, before we transformed the categories into machine learning friendly codes

# %%
houses = pickle.load(open('houses.p','rb'))

# %%
# features to inspect
houses[X_train_4.columns].dtypes[houses[X_train_4.columns].dtypes == 'category'].index
# Out:
# Index(['housetype', 'housesubtype', 'buurt_code', 'province', 'url',
#        'postcodealphadeel'],
#       dtype='object')

# %% [markdown]
# **Analysis:** To save space in the notebook, I haven't shown everything here.  The one important observation is that url is essentially a unique identifier for each home (the url from Funda for the listing) and doesn't have any information that we don't already have in other columns.  Thus, it can safely be deleted.

# %%
to_drop = ['url']
X_train = X_train.drop(to_drop, axis=1)
X_valid = X_valid.drop(to_drop, axis=1)
X_test = X_test.drop(to_drop, axis=1)

# %%
m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train, y_train)
print_score(m, X_train, y_train, X_valid, y_valid)
# Out:
# [0.08656858582157609, 0.18605897696176016, 0.967099963733307, 0.8503456696348377, 0.8598928390893226]

# %%
fi5 = rf_feat_importance(m, X_train)

# %%
plot_fi(fi5[:30]);

# %%
fi5[:30]
# Out:
#                                                   cols       imp
# 127                                             volume  0.328348
# 125                                        livingspace  0.221210
# 34                                           housetype  0.057069
# 1                                                 V1.x  0.048577
# 126                                         lotsurface  0.029052
# 133                                 yearofconstruction  0.028529
# 131                                          longitude  0.028432
# 130                                           latitude  0.026847
# 35                                        housesubtype  0.013823
# 189          Afstand tot belangrijk overstapstation:km  0.010166
# 0                                           buurt_code  0.009764
# 182               M-N Zakelijke dienstverlening:aantal  0.008697
# 123                                           province  0.007723
# 204                                       startElapsed  0.006582
# 181     K-L Financiële diensten, onroerend goed:aantal  0.006062
# 119                                              rooms  0.005569
# 147                              Actieven 15-75 jaar:%  0.004788
# 142                         Scholen binnen 3 km:aantal  0.004096
# 120                                           bedrooms  0.004084
# 153                     In bezit overige verhuurders:%  0.003209
# 188                Afstand tot treinstations totaal:km  0.003109
# 150                               Percentage bewoond:%  0.003014
# 152                        In bezit woningcorporatie:%  0.002907
# 143      Personen per soort uitkering; Bijstand:aantal  0.002828
# 149                       Percentage eengezinswoning:%  0.002791
# 190                                  postcodealphadeel  0.002787
# 156                         Niet-westers totaal:aantal  0.002737
# 208  Transacties van de laatste 12 maanden.woningen...  0.002691
# 2                                              realtor  0.002648
# 121                                  bathroom.badkamer  0.002628

# %%
top_2_train = X_train[fi5[:2].cols.values]
top_2_valid = X_valid[fi5[:2].cols.values]

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(top_2_train, y_train)
print_score(m, top_2_train, y_train, top_2_valid, y_valid)
# Out:
# [0.2609831739960067, 0.3151288478120521, 0.7009796483379269, 0.5706965745108024, 0.5824593954200981]

# %%
top_4_train = X_train[fi5[:4].cols.values]
top_4_valid = X_valid[fi5[:4].cols.values]

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(top_4_train, y_train)
print_score(m, top_4_train, y_train, top_4_valid, y_valid)
# Out:
# [0.15956823584037302, 0.23790651874338492, 0.888218838521272, 0.7553187363253052, 0.7674737836443697]

# %%
top_8_train = X_train[fi5[:8].cols.values]
top_8_valid = X_valid[fi5[:8].cols.values]

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(top_8_train, y_train)
print_score(m, top_8_train, y_train, top_8_valid, y_valid)
# Out:
# [0.11160283798000811, 0.1923182329911943, 0.9453202893390076, 0.8401071841828693, 0.847602083254983]

# %%
top_19_train = X_train[fi5[:19].cols.values]
top_19_valid = X_valid[fi5[:19].cols.values]

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(top_19_train, y_train)
print_score(m, top_19_train, y_train, top_19_valid, y_valid)
# Out:
# [0.09663030905303895, 0.18261903131667917, 0.9590076828778527, 0.8558282731926842, 0.864362497505532]

# %%
_train = X_train[fi5[:25].cols.values]
_valid = X_valid[fi5[:25].cols.values]

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(_train, y_train)
print_score(m, _train, y_train, _valid, y_valid)
# Out:
# [0.0941810303322209, 0.18155341444511466, 0.961059403011255, 0.8575059032610067, 0.8644540029598394]

# %%
X_train_5 = X_train[fi5[:30].cols.values]
X_valid_5 = X_valid[fi5[:30].cols.values]

corr = np.round(scipy.stats.spearmanr(top_19_train).correlation, 4)
corr_condensed = hc.distance.squareform(1-corr)
z = hc.linkage(corr_condensed, method='average')
fig = plt.figure(figsize=(16,20))
dendrogram = hc.dendrogram(z, labels=top_19_train.columns, 
      orientation='left', leaf_font_size=16)
plt.show()

# %% [markdown]
# **Final Analysis:** It appears we have made all the improvements we can for now.  We'll serialize the datasets and do some more intensive fine-tuning in a separate notebook

# %%
houses_final = houses[top_19_train.columns]
houses_final.rename(index=str, columns={'V1.x':'postcode5'})
# Out:
#        volume  livingspace        housetype  postcode5  lotsurface  \
# 0       255.0         97.0      appartement      48990         NaN
# 1       264.0        106.0      appartement      48989         NaN
# 2       335.0        127.0      appartement      48988         NaN
# 3       300.0        130.0  eengezinswoning      47652       142.0
# 4       260.0         94.0      appartement      47915         NaN
# 5       365.0        107.0      appartement      48987         NaN
# 6       287.0        112.0      appartement      48986         NaN
# 7       452.0        140.0  eengezinswoning      48003       188.0
# 8       300.0        100.0  eengezinswoning      47735        90.0
# 9       425.0        115.0  eengezinswoning      49042       585.0
# 10      675.0        180.0            villa      48753       506.0
# 11      340.0        115.0  eengezinswoning      48628       179.0
# 12     1457.0        282.0            villa      48065       618.0
# 13      380.0        115.0      appartement      48167         NaN
# 14      360.0        115.0  eengezinswoning      47753       113.0
# 15      315.0        115.0  eengezinswoning      48434       140.0
# 16      750.0        250.0            villa      48981       375.0
# 17      295.0         95.0  eengezinswoning      48074       179.0
# 18      310.0        100.0  eengezinswoning      47965       167.0
# 19      265.0         65.0  eengezinswoning      48536        90.0
# 20      210.0         70.0  eengezinswoning      47935       213.0
# 21      400.0        125.0  eengezinswoning      48994       190.0
# 22      325.0        110.0      appartement      48304         NaN
# 23      555.0        180.0  eengezinswoning      48004       425.0
# 24      320.0         92.0  eengezinswoning      47809       140.0
# 25      430.0        130.0  eengezinswoning      49040       132.0
# 26      300.0         75.0         bungalow      49034      1100.0
# 27      372.0         98.0  eengezinswoning      47984       131.0
# 28      370.0        105.0  eengezinswoning      47936        92.0
# 29      185.0         67.0      appartement      48162         NaN
# ...       ...          ...              ...        ...         ...
# 78265   488.0        119.0    woonboerderij      70149     12320.0
# 78266   343.0        132.0      appartement       3619         NaN
# 78267   325.0         89.0  eengezinswoning      60509       115.0
# 78268   200.0          NaN      appartement      75139         NaN
# 78269   695.0        180.0            villa      13850       499.0
# 78270   430.0        130.0  eengezinswoning       5169       145.0
# 78271   600.0          NaN  eengezinswoning      39538         NaN
# 78272   405.0        117.0  eengezinswoning      14349       137.0
# 78273   580.0        131.0        herenhuis      21220       459.0
# 78274   395.0        114.0     grachtenpand       6559        48.0
# 78275   200.0         80.0      appartement      46365         NaN
# 78276   210.0         69.0      appartement      28234         NaN
# 78277   988.0        220.0        herenhuis      59072       281.0
# 78278  1823.0        429.0        herenhuis      59978       264.0
# 78279   335.0         90.0      appartement       6660         NaN
# 78280   325.0          NaN  eengezinswoning      42194         NaN
# 78281   391.0        104.0  eengezinswoning      52185       285.0
# 78282   425.0        113.0  eengezinswoning       6323       105.0
# 78283  1325.0          NaN    woonboerderij      71395         NaN
# 78284   502.0        160.0      appartement      59803         NaN
# 78285   483.0        130.0  eengezinswoning      53036       224.0
# 78286   290.0        101.0  eengezinswoning       6667       184.0
# 78287   435.0        139.0  eengezinswoning      77659       416.0
# 78288   415.0        163.0  eengezinswoning      57520       143.0
# 78289   257.0         75.0      appartement      78381         NaN
# 78290   256.0         84.0      appartement       5522         NaN
# 78291   215.0         67.0      appartement      13877         NaN
# 78292   570.0        160.0  eengezinswoning      44147       106.0
# 78293   400.0          NaN    woonboerderij      76152         NaN
# 78294   310.0        110.0      appartement      84277         NaN
#
#        yearofconstruction  longitude   latitude            housesubtype  \
# 0                  2013.0   5.132951  51.484440             portiekflat
# 1                  2013.0   5.132951  51.484440             portiekflat
# 2                  2013.0   5.132951  51.484440             portiekflat
# 3                  1994.0   5.092662  51.568063            tussenwoning
# 4                  2005.0   5.090770  51.542778             galerijflat
# 5                  2013.0   5.132951  51.484440             portiekflat
# 6                  2013.0   5.132951  51.484440             portiekflat
# 7                  1980.0   5.037728  51.544504              eindwoning
# 8                  1933.0   5.107673  51.560066              hoekwoning
# 9                  1955.0   5.173271  51.474566      vrijstaande woning
# 10                 1980.0   5.152315  51.587808      vrijstaande woning
# 11                 1988.0   5.075018  51.528181              hoekwoning
# 12                 2009.0   4.980205  51.580658      geschakelde woning
# 13                 1998.0   5.091460  51.557114             portiekflat
# 14                 1939.0   5.096726  51.548512              eindwoning
# 15                 1997.0   4.989551  51.588109            tussenwoning
# 16                    NaN   5.138899  51.484282      vrijstaande woning
# 17                 2000.0   4.979962  51.583420            tussenwoning
# 18                 1921.0   5.077380  51.553874            tussenwoning
# 19                 1905.0   5.079603  51.573888            tussenwoning
# 20                 1926.0   5.069332  51.546004              eindwoning
# 21                    NaN   5.137627  51.487521  halfvrijstaande woning
# 22                 1967.0   5.059733  51.574308             maisonnette
# 23                 1982.0   5.038292  51.545998              hoekwoning
# 24                 1950.0   5.099924  51.543455            tussenwoning
# 25                 2009.0   5.137369  51.463885            tussenwoning
# 26                    NaN   5.137692  51.461651      vrijstaande woning
# 27                 1930.0   5.063522  51.552167              eindwoning
# 28                 2015.0   5.067368  51.546092            tussenwoning
# 29                 1989.0   5.083449  51.554960             galerijflat
# ...                   ...        ...        ...                     ...
# 78265              1964.0   6.403768  52.293511      vrijstaande woning
# 78266              1983.0   4.963026  52.340227             bovenwoning
# 78267              1952.0   5.890622  50.918610     2-onder-1-kapwoning
# 78268              1969.0   6.087462  52.522511             maisonnette
# 78269              1920.0   4.622419  52.354709      vrijstaande woning
# 78270              1972.0   5.243150  52.254131            tussenwoning
# 78271              1980.0   5.502505  52.077424      vrijstaande woning
# 78272              1990.0   4.661278  52.302416            tussenwoning
# 78273              1951.0   4.387846  52.007857              hoekwoning
# 78274              1898.0   5.043737  52.305820            tussenwoning
# 78275              1962.0   4.793398  51.568305             portiekflat
# 78276              1914.0   4.391726  51.913816             bovenwoning
# 78277              1913.0   5.871562  51.101448      geschakelde woning
# 78278              1906.0   5.701132  50.847383            tussenwoning
# 78279              2008.0   4.976239  52.278267           benedenwoning
# 78280              1993.0   3.949111  51.712048     2-onder-1-kapwoning
# 78281              1965.0   5.682223  51.744432     2-onder-1-kapwoning
# 78282              2011.0   5.278596  52.357371              hoekwoning
# 78283              1906.0   6.783097  52.282392      vrijstaande woning
# 78284              1800.0   5.686145  50.851841             bovenwoning
# 78285              1991.0   5.541608  51.607826  halfvrijstaande woning
# 78286              1963.0   5.027189  52.274219              hoekwoning
# 78287              1993.0   5.674118  52.679740     2-onder-1-kapwoning
# 78288                 NaN   6.143428  51.373695            tussenwoning
# 78289              1976.0   5.917142  52.954204           benedenwoning
# 78290              1985.0   5.210923  52.375597             portiekflat
# 78291              1976.0   4.633240  52.352639             portiekflat
# 78292              1921.0   4.294300  51.484077              hoekwoning
# 78293              2011.0   6.383206  52.442120            tussenwoning
# 78294              2009.0   6.543447  53.225263             portiekflat
#
#        Afstand tot belangrijk overstapstation:km  buurt_code  \
# 0                                            9.9  BU07980000
# 1                                            9.9  BU07980000
# 2                                            9.9  BU07980000
# 3                                            1.5  BU08550206
# 4                                            2.8  BU08550601
# 5                                            9.9  BU07980000
# 6                                            9.9  BU07980000
# 7                                            4.1  BU08550603
# 8                                            2.0  BU08550101
# 9                                           12.7  BU07980300
# 10                                           6.4  BU08550703
# 11                                           4.4  BU07850303
# 12                                           8.7  BU08550807
# 13                                           0.7  BU08550000
# 14                                           1.9  BU08550104
# 15                                           8.6  BU08550805
# 16                                           9.9  BU07980000
# 17                                           8.7  BU08550807
# 18                                           2.0  BU08550107
# 19                                           2.0  BU08550203
# 20                                           2.0  BU08550107
# 21                                           9.9  BU07980000
# 22                                           3.1  BU08550303
# 23                                           4.1  BU08550603
# 24                                           2.8  BU08550601
# 25                                          12.8  BU07980100
# 26                                          12.8  BU07980100
# 27                                           2.0  BU08550107
# 28                                           2.0  BU08550107
# 29                                           0.7  BU08550000
# ...                                          ...         ...
# 78265                                       18.0  BU17420500
# 78266                                        4.0  BU03840114
# 78267                                        7.8  BU09510000
# 78268                                        2.6  BU01933000
# 78269                                        4.5  BU03970000
# 78270                                        5.9  BU04170001
# 78271                                       14.4  BU02790008
# 78272                                        9.5  BU03940113
# 78273                                        9.5  BU05032808
# 78274                                        1.4  BU04570001
# 78275                                        3.6  BU07580303
# 78276                                        6.4  BU06060304
# 78277                                       12.9  BU17110524
# 78278                                        0.6  BU09350006
# 78279                                        7.7  BU07360400
# 78280                                       45.1  BU16760200
# 78281                                       19.5  BU16850100
# 78282                                        6.7  BU00340503
# 78283                                        2.3  BU01640100
# 78284                                        1.8  BU09350003
# 78285                                       20.8  BU08600002
# 78286                                        6.0  BU19040804
# 78287                                       31.3  BU01710837
# 78288                                        2.5  BU09832203
# 78289                                        2.3  BU00740104
# 78290                                        0.6  BU00340209
# 78291                                        5.9  BU03970001
# 78292                                       15.2  BU07480005
# 78293                                       25.8  BU01750702
# 78294                                        2.7  BU00141001
#
#        M-N Zakelijke dienstverlening:aantal       province  startElapsed  \
# 0                                     200.0  Noord-Brabant        2293.0
# 1                                     200.0  Noord-Brabant        2293.0
# 2                                     200.0  Noord-Brabant        2293.0
# 3                                      40.0  Noord-Brabant        3858.0
# 4                                      80.0  Noord-Brabant        4021.0
# 5                                     200.0  Noord-Brabant        2293.0
# 6                                     200.0  Noord-Brabant        2293.0
# 7                                     200.0  Noord-Brabant        4065.0
# 8                                      70.0  Noord-Brabant        4084.0
# 9                                      60.0  Noord-Brabant        3489.0
# 10                                     60.0  Noord-Brabant        3804.0
# 11                                     40.0  Noord-Brabant        4010.0
# 12                                    125.0  Noord-Brabant        3484.0
# 13                                    280.0  Noord-Brabant        3873.0
# 14                                    100.0  Noord-Brabant        4083.0
# 15                                    220.0  Noord-Brabant        3799.0
# 16                                    200.0  Noord-Brabant        1416.0
# 17                                    125.0  Noord-Brabant        4086.0
# 18                                    190.0  Noord-Brabant        3946.0
# 19                                    100.0  Noord-Brabant        4040.0
# 20                                    190.0  Noord-Brabant        4077.0
# 21                                    200.0  Noord-Brabant        3909.0
# 22                                    115.0  Noord-Brabant        4049.0
# 23                                    200.0  Noord-Brabant        4117.0
# 24                                     80.0  Noord-Brabant        4114.0
# 25                                     10.0  Noord-Brabant        3911.0
# 26                                     10.0  Noord-Brabant        2949.0
# 27                                    190.0  Noord-Brabant        3873.0
# 28                                    190.0  Noord-Brabant        4127.0
# 29                                    280.0  Noord-Brabant        3195.0
# ...                                     ...            ...           ...
# 78265                                   5.0     Overijssel        4534.0
# 78266                                  45.0  Noord-Holland        4533.0
# 78267                                  80.0        Limburg        4545.0
# 78268                                  40.0     Overijssel        4517.0
# 78269                                 135.0  Noord-Holland        4545.0
# 78270                                 185.0  Noord-Holland        4519.0
# 78271                                   NaN     Gelderland        3905.0
# 78272                                 110.0  Noord-Holland        4549.0
# 78273                                   NaN   Zuid-Holland        4520.0
# 78274                                  45.0  Noord-Holland        4533.0
# 78275                                 265.0  Noord-Brabant        4554.0
# 78276                                  15.0   Zuid-Holland        4552.0
# 78277                                  65.0        Limburg        4286.0
# 78278                                 340.0        Limburg        4548.0
# 78279                                 270.0        Utrecht        4547.0
# 78280                                  20.0        Zeeland        3748.0
# 78281                                  30.0  Noord-Brabant        4380.0
# 78282                                   NaN      Flevoland        4415.0
# 78283                                  40.0     Overijssel        4574.0
# 78284                                  65.0        Limburg        4509.0
# 78285                                  30.0  Noord-Brabant        4519.0
# 78286                                  35.0        Utrecht        4524.0
# 78287                                  25.0      Flevoland        4516.0
# 78288                                  15.0        Limburg        4554.0
# 78289                                  75.0      Friesland        4504.0
# 78290                                  30.0      Flevoland        4497.0
# 78291                                 160.0  Noord-Holland        4492.0
# 78292                                  25.0  Noord-Brabant        4434.0
# 78293                                   NaN     Overijssel        4449.0
# 78294                                  55.0      Groningen        4534.0
#
#        K-L Financiële diensten, onroerend goed:aantal  rooms  \
# 0                                                80.0    3.0
# 1                                                80.0    2.0
# 2                                                80.0    3.0
# 3                                                10.0    5.0
# 4                                                15.0    3.0
# 5                                                80.0    3.0
# 6                                                80.0    3.0
# 7                                                95.0    5.0
# 8                                                15.0    3.0
# 9                                                25.0    7.0
# 10                                               20.0    5.0
# 11                                               10.0    4.0
# 12                                               30.0    8.0
# 13                                              110.0    3.0
# 14                                               20.0    5.0
# 15                                               45.0    4.0
# 16                                               80.0    8.0
# 17                                               30.0    5.0
# 18                                               30.0    4.0
# 19                                               15.0    2.0
# 20                                               30.0    3.0
# 21                                               80.0    6.0
# 22                                               20.0    5.0
# 23                                               95.0    6.0
# 24                                               15.0    5.0
# 25                                               10.0    5.0
# 26                                               10.0    4.0
# 27                                               30.0    6.0
# 28                                               30.0    4.0
# 29                                              110.0    2.0
# ...                                               ...    ...
# 78265                                             5.0    7.0
# 78266                                            15.0    5.0
# 78267                                            25.0    9.0
# 78268                                             0.0    4.0
# 78269                                            50.0    8.0
# 78270                                            85.0    5.0
# 78271                                             NaN    7.0
# 78272                                            50.0    6.0
# 78273                                             NaN    5.0
# 78274                                            25.0    4.0
# 78275                                           140.0    3.0
# 78276                                             0.0    3.0
# 78277                                            35.0    8.0
# 78278                                           135.0   12.0
# 78279                                           120.0    3.0
# 78280                                            10.0    7.0
# 78281                                            15.0    4.0
# 78282                                             NaN    4.0
# 78283                                            15.0   11.0
# 78284                                            30.0    7.0
# 78285                                             5.0    5.0
# 78286                                            10.0    5.0
# 78287                                            10.0    8.0
# 78288                                             0.0    6.0
# 78289                                            25.0    2.0
# 78290                                             5.0    5.0
# 78291                                            70.0    2.0
# 78292                                            10.0    5.0
# 78293                                             NaN    7.0
# 78294                                            15.0    3.0
#
#        Actieven 15-75 jaar:%  Scholen binnen 3 km:aantal  bedrooms
# 0                       60.1                         3.2       2.0
# 1                       60.1                         3.2       1.0
# 2                       60.1                         3.2       2.0
# 3                       54.6                        18.8       4.0
# 4                       48.4                         9.5       2.0
# 5                       60.1                         3.2       2.0
# 6                       60.1                         3.2       2.0
# 7                       59.7                         6.9       4.0
# 8                       66.2                        15.6       2.0
# 9                       63.0                         1.3       5.0
# 10                      55.6                         4.0       4.0
# 11                      62.2                         9.1       3.0
# 12                      68.4                        12.7       4.0
# 13                      45.5                        22.0       2.0
# 14                      53.4                        16.6       4.0
# 15                      66.7                        12.3       3.0
# 16                      60.1                         3.2       3.0
# 17                      68.4                        12.7       3.0
# 18                      52.7                        19.0       3.0
# 19                      55.5                        24.1       1.0
# 20                      52.7                        19.0       2.0
# 21                      60.1                         3.2       4.0
# 22                      48.6                        14.4       3.0
# 23                      59.7                         6.9       5.0
# 24                      48.4                         9.5       4.0
# 25                      64.8                         1.9       3.0
# 26                      64.8                         1.9       3.0
# 27                      52.7                        19.0       3.0
# 28                      52.7                        19.0       3.0
# 29                      45.5                        22.0       1.0
# ...                      ...                         ...       ...
# 78265                   60.6                         2.2       5.0
# 78266                   61.2                         9.9       4.0
# 78267                   52.4                         2.3       3.0
# 78268                   42.0                        17.2       3.0
# 78269                   57.1                        15.4       5.0
# 78270                   52.0                        11.9       4.0
# 78271                    NaN                         5.0       6.0
# 78272                   64.6                        23.3       4.0
# 78273                    NaN                        10.4       4.0
# 78274                   54.8                         6.0       2.0
# 78275                   62.6                        10.8       2.0
# 78276                   54.2                        18.6       2.0
# 78277                   55.4                         5.5       3.0
# 78278                   46.7                        17.1       6.0
# 78279                   62.1                         4.0       2.0
# 78280                   62.1                         1.0       4.0
# 78281                   60.8                         1.4       3.0
# 78282                    NaN                         0.0       NaN
# 78283                   52.4                        10.9       6.0
# 78284                   37.0                        13.5       3.0
# 78285                   58.3                         5.2       4.0
# 78286                   64.0                         2.0       3.0
# 78287                   68.9                         3.0       4.0
# 78288                   59.4                        10.8       4.0
# 78289                   54.8                        11.6       1.0
# 78290                   51.3                        27.0       3.0
# 78291                   59.3                         9.8       1.0
# 78292                   47.4                        13.2       4.0
# 78293                    NaN                         0.9       4.0
# 78294                   44.2                        11.8       2.0
#
# [78295 rows x 19 columns]

# %%
houses_final.head()
# Out:
#    volume  livingspace        housetype   V1.x  lotsurface  \
# 0   255.0         97.0      appartement  48990         NaN
# 1   264.0        106.0      appartement  48989         NaN
# 2   335.0        127.0      appartement  48988         NaN
# 3   300.0        130.0  eengezinswoning  47652       142.0
# 4   260.0         94.0      appartement  47915         NaN
#
#    yearofconstruction  longitude   latitude  housesubtype  \
# 0              2013.0   5.132951  51.484440   portiekflat
# 1              2013.0   5.132951  51.484440   portiekflat
# 2              2013.0   5.132951  51.484440   portiekflat
# 3              1994.0   5.092662  51.568063  tussenwoning
# 4              2005.0   5.090770  51.542778   galerijflat
#
#    Afstand tot belangrijk overstapstation:km  buurt_code  \
# 0                                        9.9  BU07980000
# 1                                        9.9  BU07980000
# 2                                        9.9  BU07980000
# 3                                        1.5  BU08550206
# 4                                        2.8  BU08550601
#
#    M-N Zakelijke dienstverlening:aantal       province  startElapsed  \
# 0                                 200.0  Noord-Brabant        2293.0
# 1                                 200.0  Noord-Brabant        2293.0
# 2                                 200.0  Noord-Brabant        2293.0
# 3                                  40.0  Noord-Brabant        3858.0
# 4                                  80.0  Noord-Brabant        4021.0
#
#    K-L Financiële diensten, onroerend goed:aantal  rooms  \
# 0                                            80.0    3.0
# 1                                            80.0    2.0
# 2                                            80.0    3.0
# 3                                            10.0    5.0
# 4                                            15.0    3.0
#
#    Actieven 15-75 jaar:%  Scholen binnen 3 km:aantal  bedrooms
# 0                   60.1                         3.2       2.0
# 1                   60.1                         3.2       1.0
# 2                   60.1                         3.2       2.0
# 3                   54.6                        18.8       4.0
# 4                   48.4                         9.5       2.0

# %%
display_all(houses_final['Afstand tot belangrijk overstapstation:km'].value_counts())
# Out:
# 1.8     939
# 1.5     886
# 2.2     815
# 3.0     795
# 2.0     745
# 3.5     733
# 2.3     732
# 2.5     693
# 1.7     685
# 4.5     685
# 8.6     681
# 3.1     681
# 6.4     676
# 1.9     675
# 3.4     639
# 3.3     633
# 2.6     632
# 6.0     611
# 5.0     607
# 4.0     604
# 5.8     602
# 2.7     597
# 3.9     586
# 2.8     582
# 1.4     577
# 4.1     571
# 7.5     567
# 4.2     559
# 3.8     559
# 2.4     557
# 4.7     542
# 8.0     541
# 6.7     532
# 1.2     524
# 5.6     523
# 8.1     520
# 6.5     499
# 5.5     495
# 1.0     492
# 8.2     491
# 3.6     488
# 2.1     485
# 10.4    483
# 8.7     479
# 5.2     479
# 11.5    478
# 4.6     471
# 9.0     462
# 3.2     458
# 5.1     453
# 1.3     443
# 9.9     433
# 4.9     428
# 1.1     427
# 5.9     425
# 11.1    424
# 7.6     420
# 0.8     419
# 7.7     417
# 1.6     415
# 7.3     414
# 0.9     405
# 7.4     402
# 6.9     402
# 10.9    400
# 8.4     396
# 8.3     396
# 5.3     390
# 9.8     385
# 3.7     378
# 2.9     362
# 4.4     361
# 10.1    357
# 4.3     356
# 14.2    356
# 6.3     354
# 6.1     350
# 6.8     349
# 7.0     348
# 6.6     348
# 5.7     344
# 5.4     341
# 7.2     340
# 12.6    339
# 13.1    338
# 10.8    337
# 13.7    337
# 10.3    336
# 12.2    332
# 9.4     329
# 13.9    327
# 10.5    325
# 12.5    321
# 11.2    317
# 12.9    316
# 10.7    315
# 8.5     314
# 9.7     312
# 7.1     303
# 9.6     302
# 6.2     302
# 14.6    301
# 15.0    301
# 11.8    300
# 10.2    300
# 4.8     297
# 12.3    295
# 12.1    292
# 16.2    291
# 15.3    286
# 9.2     285
# 10.0    283
# 9.1     283
# 14.8    283
# 11.9    280
# 7.9     279
# 14.7    275
# 12.0    275
# 9.5     275
# 9.3     275
# 11.3    274
# 7.8     273
# 8.9     267
# 12.7    261
# 14.0    254
# 11.7    249
# 11.6    249
# 11.4    246
# 11.0    239
# 8.8     239
# 25.6    238
# 15.2    234
# 14.5    233
# 15.7    231
# 17.0    229
# 16.3    228
# 13.4    228
# 15.5    226
# 14.4    225
# 15.6    225
# 22.3    222
# 17.1    222
# 13.5    219
# 15.8    218
# 13.0    217
# 15.1    216
# 16.5    213
# 13.6    207
# 13.2    206
# 12.8    203
# 14.1    196
# 23.0    196
# 18.7    195
# 16.0    193
# 0.7     184
# 15.4    183
# 0.6     176
# 13.8    176
# 14.3    176
# 18.5    175
# 16.4    175
# 19.1    174
# 12.4    174
# 14.9    169
# 19.4    169
# 25.8    168
# 15.9    168
# 20.5    166
# 16.8    166
# 18.9    166
# 16.1    165
# 13.3    164
# 18.4    163
# 17.7    161
# 20.6    154
# 20.0    147
# 10.6    145
# 27.1    145
# 16.6    144
# 24.5    144
# 25.3    144
# 21.6    143
# 17.8    143
# 19.5    140
# 23.2    139
# 25.9    138
# 19.0    137
# 18.6    137
# 18.1    136
# 24.4    135
# 16.7    134
# 22.9    133
# 21.2    130
# 19.9    128
# 25.2    127
# 20.9    126
# 18.3    125
# 17.6    125
# 22.8    124
# 17.4    123
# 23.7    119
# 22.0    119
# 19.7    118
# 26.9    118
# 20.7    114
# 24.9    112
# 24.6    110
# 19.3    109
# 21.4    107
# 26.8    107
# 22.4    106
# 20.3    106
# 19.8    106
# 22.7    106
# 20.8    106
# 23.5    105
# 18.2    103
# 21.8    102
# 21.7    100
# 18.8     99
# 17.5     99
# 23.8     97
# 23.1     97
# 19.6     97
# 24.1     95
# 17.9     92
# 26.5     92
# 24.8     91
# 23.6     91
# 22.2     89
# 17.2     89
# 20.1     87
# 17.3     86
# 0.5      85
# 24.2     85
# 23.4     83
# 31.2     82
# 28.0     82
# 25.1     82
# 37.2     82
# 27.0     81
# 21.0     81
# 20.4     81
# 24.3     78
# 25.5     78
# 18.0     77
# 25.0     74
# 19.2     74
# 22.1     73
# 27.4     71
# 24.7     70
# 21.9     69
# 26.4     69
# 28.2     68
# 27.8     65
# 27.5     64
# 16.9     64
# 22.6     63
# 30.1     63
# 25.7     59
# 26.1     58
# 32.6     58
# 29.0     57
# 28.9     57
# 30.8     56
# 21.5     56
# 26.6     55
# 26.0     54
# 32.3     53
# 25.4     53
# 20.2     52
# 26.7     52
# 32.4     52
# 30.3     50
# 27.6     50
# 27.7     50
# 27.3     49
# 26.2     49
# 0.4      49
# 31.5     49
# 23.9     49
# 38.6     48
# 33.8     47
# 30.6     46
# 29.6     45
# 29.8     45
# 37.5     44
# 31.7     44
# 30.5     44
# 27.2     43
# 26.3     43
# 31.3     42
# 24.0     42
# 28.6     38
# 33.7     37
# 28.5     36
# 32.7     35
# 35.5     34
# 29.3     34
# 29.2     34
# 35.8     34
# 39.1     33
# 28.7     33
# 22.5     33
# 34.1     32
# 34.9     32
# 34.4     32
# 21.3     32
# 36.8     32
# 28.1     31
# 34.5     31
# 31.8     31
# 34.2     30
# 31.6     30
# 32.9     29
# 53.5     29
# 23.3     29
# 30.0     28
# 38.4     28
# 29.7     28
# 32.2     27
# 37.0     26
# 37.1     26
# 0.3      26
# 42.6     26
# 35.1     25
# 37.6     25
# 30.9     25
# 49.6     25
# 33.3     25
# 30.2     25
# 34.6     24
# 52.7     24
# 21.1     24
# 46.3     24
# 29.1     22
# 34.8     22
# 38.1     22
# 33.9     21
# 28.4     21
# 41.2     21
# 28.3     21
# 29.9     21
# 41.6     18
# 36.6     18
# 39.9     18
# 29.4     18
# 33.6     18
# 36.1     17
# 32.5     17
# 40.7     17
# 29.5     17
# 30.4     17
# 48.0     17
# 43.1     16
# 50.2     15
# 39.8     15
# 35.3     14
# 35.9     14
# 31.1     14
# 47.6     13
# 38.3     13
# 41.7     13
# 41.3     13
# 33.2     13
# 33.5     12
# 42.0     12
# 35.6     12
# 51.0     12
# 39.3     12
# 32.8     12
# 52.2     11
# 39.6     11
# 43.6     10
# 31.4     10
# 27.9     10
# 35.0     10
# 59.1      9
# 34.3      9
# 37.9      9
# 37.8      9
# 39.4      9
# 62.1      9
# 28.8      9
# 43.5      9
# 42.9      8
# 47.0      8
# 44.2      8
# 59.4      8
# 31.9      8
# 40.9      8
# 50.6      8
# 33.1      8
# 36.0      8
# 43.3      7
# 40.6      7
# 31.0      7
# 43.9      7
# 39.7      7
# 54.3      7
# 56.8      7
# 40.4      7
# 63.6      7
# 59.9      7
# 32.1      6
# 44.9      6
# 30.7      6
# 51.5      6
# 39.2      6
# 38.8      5
# 38.7      5
# 49.0      5
# 33.4      5
# 45.1      5
# 49.1      5
# 34.7      5
# 52.1      5
# 57.4      5
# 56.9      5
# 48.1      5
# 38.0      4
# 45.4      4
# 36.7      4
# 49.7      4
# 38.2      4
# 36.5      4
# 65.1      4
# 42.5      4
# 35.2      4
# 43.2      4
# 51.6      3
# 47.5      3
# 35.7      3
# 48.5      3
# 39.0      3
# 45.5      3
# 39.5      3
# 42.1      3
# 50.4      3
# 61.8      3
# 64.7      3
# 41.4      3
# 61.3      3
# 61.2      2
# 45.7      2
# 53.0      2
# 54.1      2
# 58.4      2
# 58.3      2
# 66.8      2
# 40.2      2
# 44.6      2
# 33.0      2
# 60.1      2
# 62.5      2
# 38.9      2
# 42.2      2
# 37.7      2
# 54.0      2
# 42.8      2
# 36.9      2
# 32.0      2
# 50.0      2
# 38.5      2
# 51.3      2
# 46.0      2
# 41.9      2
# 56.3      2
# 40.3      1
# 51.2      1
# 37.3      1
# 40.8      1
# 68.1      1
# 66.4      1
# 55.3      1
# 69.2      1
# 61.6      1
# 40.1      1
# 34.0      1
# 37.4      1
# 42.3      1
# 41.8      1
# 41.0      1
# 44.4      1
# 52.8      1
# 43.4      1
# 48.8      1
# 53.8      1
# 50.9      1
# 36.4      1
# 43.8      1
# 58.0      1
# 42.7      1
# 54.5      1
# Name: Afstand tot belangrijk overstapstation:km, dtype: int64

# %%
top_19_test = X_test[top_19_train.columns]

# %%
pickle.dump([top_19_train, y_train], open('train_final.p','wb'))
pickle.dump([top_19_valid, y_valid], open('valid_final.p','wb'))
pickle.dump([top_19_test, y_test], open('test_final.p','wb'))

# %%
pickle.dump(houses_final, open('houses_final.p','wb'))
