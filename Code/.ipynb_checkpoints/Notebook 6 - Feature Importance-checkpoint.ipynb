# %%
import pandas as pd
import numpy as np
import re
import math
import pickle
import scipy
import matplotlib.pyplot as plt

from sklearn import metrics
from preprocessing import *
from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.model_selection import GridSearchCV
from scipy.cluster import hierarchy as hc
# import jtplot submodule from jupyterthemes
from jupyterthemes import jtplot

# currently installed theme will be used to
# set plot style if no arguments provided
# jtplot.style()

# %%
best = pickle.load(open('nb5_best.p','rb'))
X_train, y_train = pickle.load(open('train.p','rb'))
X_valid, y_valid = pickle.load(open('valid.p','rb'))
X_test, y_test = pickle.load(open('test.p','rb'))

# %% [markdown]
# **Feature Importance**

# %%
fi
# Out:
#                                                   cols       imp
# 127                                        livingspace  0.292510
# 129                                             volume  0.239861
# 163               Gemiddelde woningwaarde:x 1 000 euro  0.084530
# 36                                           housetype  0.049925
# 154        Gemiddeld inkomen per inwoner :x 1 000 euro  0.031604
# 128                                         lotsurface  0.026540
# 136                                 yearofconstruction  0.018964
# 1                                                 V1.x  0.018106
# 37                                        housesubtype  0.014227
# 139                    Meest voorkomende postcode:code  0.012754
# 153  Gemiddeld inkomen per inkomensontvanger :x 1 0...  0.010443
# 131                                 postcodenummerdeel  0.010310
# 133                                           latitude  0.009767
# 134                                          longitude  0.008820
# 156                 20% personen met hoogste inkomen:%  0.008450
# 159              20% huishoudens met hoogste inkomen:%  0.007258
# 164                       Percentage eengezinswoning:%  0.005889
# 178        Bevolkingsdichtheid:aantal inwoners per km²  0.005386
# 204          Afstand tot belangrijk overstapstation:km  0.004895
# 147                         Scholen binnen 3 km:aantal  0.004731
# 158              40% huishoudens met laagste inkomen:%  0.004020
# 166                                     Koopwoningen:%  0.003591
# 121                                              rooms  0.003447
# 177               Gemiddelde huishoudensgrootte:aantal  0.002938
# 219                                       startElapsed  0.002894
# 205                                  postcodealphadeel  0.002722
# 132                                            address  0.002551
# 2                                                  url  0.002518
# 137                                               V1.y  0.002399
# 168                     In bezit overige verhuurders:%  0.002300
# ..                                                 ...       ...
# 273                                    startQuarter_na  0.000000
# 274                                      startMonth_na  0.000000
# 275                                       startWeek_na  0.000000
# 276                                        startDay_na  0.000000
# 277                                  startDayofweek_na  0.000000
# 278                                  startDayofyear_na  0.000000
# 272                                       startYear_na  0.000000
# 72                        details.gedeeltelijkverhuurd  0.000000
# 257                  In bezit overige verhuurders:%_na  0.000000
# 242        Personen per soort uitkering; AOW:aantal_na  0.000000
# 29                                       feature.sauna  0.000000
# 31                                 feature.stoomcabine  0.000000
# 33                                     feature.jacuzzi  0.000000
# 34                            feature.satellietschotel  0.000000
# 35                                   feature.windmolen  0.000000
# 142                           Soort regio:omschrijving  0.000000
# 65                                details.gemeubileerd  0.000000
# 113                                       certificate.  0.000000
# 112                        certificate.brandveiligheid  0.000000
# 11                                     bathroom.zitbad  0.000000
# 111                     certificate.algemenewoningkeur  0.000000
# 105                certificate.kiwaveiligwonenkeurmerk  0.000000
# 103                                 insulation.ecobouw  0.000000
# 218                                 startIs_year_start  0.000000
# 228                          bathroom.aparte toilet_na  0.000000
# 231                                          volume_na  0.000000
# 233                     Mate van stedelijkheid:code_na  0.000000
# 235                 Afstand tot grote supermarkt:km_na  0.000000
# 240         Personen per soort uitkering; AO:aantal_na  0.000000
# 279                                    startElapsed_na  0.000000
#
# [280 rows x 2 columns]

# %%
# compute and plot the feature importance for all the columns in the dataframe
fi = rf_feat_importance(best, X_train)
fi.plot('cols', 'imp', figsize=(20,12), legend=False);

# %% [markdown]
# **Analysis:** as usual, there are only a handful of columns that really account for the variance in prices we have in our dataset.  Let's inspect the larger values:

# %%
plot_fi(fi[:30]);

# %% [markdown]
# **Analysis:** perhaps not surpisingly, the factors that are driving price appear to be:
#
# 1) the size of the house <br>
# 2) the appraised value <br>
# 3) average income of residents <br>
# 4) house type (could be correlated with size) <br>
# 5) location (postcode, lat & lon)
#
# Some of these are not housing attributes, per se, and aren't really all that interesting because they describe the people who live in the houses rather than the houses themselves.  If you trying to learn about which features are driving house prices, these aren't very helpful.  We'll explore in greater detail later.  For now, let's simplify the model by using only the most relevant information.

# %%
display_all(fi)
# Out:
#                                                   cols           imp
# 127                                        livingspace  2.925103e-01
# 129                                             volume  2.398607e-01
# 163               Gemiddelde woningwaarde:x 1 000 euro  8.453042e-02
# 36                                           housetype  4.992458e-02
# 154        Gemiddeld inkomen per inwoner :x 1 000 euro  3.160427e-02
# 128                                         lotsurface  2.653972e-02
# 136                                 yearofconstruction  1.896389e-02
# 1                                                 V1.x  1.810641e-02
# 37                                        housesubtype  1.422723e-02
# 139                    Meest voorkomende postcode:code  1.275350e-02
# 153  Gemiddeld inkomen per inkomensontvanger :x 1 0...  1.044348e-02
# 131                                 postcodenummerdeel  1.031021e-02
# 133                                           latitude  9.767168e-03
# 134                                          longitude  8.819502e-03
# 156                 20% personen met hoogste inkomen:%  8.450090e-03
# 159              20% huishoudens met hoogste inkomen:%  7.258395e-03
# 164                       Percentage eengezinswoning:%  5.889326e-03
# 178        Bevolkingsdichtheid:aantal inwoners per km²  5.386012e-03
# 204          Afstand tot belangrijk overstapstation:km  4.894912e-03
# 147                         Scholen binnen 3 km:aantal  4.731154e-03
# 158              40% huishoudens met laagste inkomen:%  4.019662e-03
# 166                                     Koopwoningen:%  3.591032e-03
# 121                                              rooms  3.446922e-03
# 177               Gemiddelde huishoudensgrootte:aantal  2.938147e-03
# 219                                       startElapsed  2.894054e-03
# 205                                  postcodealphadeel  2.721606e-03
# 132                                            address  2.551383e-03
# 2                                                  url  2.517510e-03
# 137                                               V1.y  2.399122e-03
# 168                     In bezit overige verhuurders:%  2.299935e-03
# 0                                           buurt_code  2.289009e-03
# 3                                              realtor  2.221592e-03
# 203                Afstand tot treinstations totaal:km  2.211050e-03
# 130                                        housenumber  2.194803e-03
# 5                                            wijk_code  2.137352e-03
# 197               M-N Zakelijke dienstverlening:aantal  2.126521e-03
# 157                              Actieven 15-75 jaar:%  2.073963e-03
# 161             Huish. onder of rond sociaal minimum:%  1.956299e-03
# 125                                           province  1.946908e-03
# 160                 Huishoudens met een laag inkomen:%  1.877323e-03
# 210                                           startDay  1.846836e-03
# 155                 40% personen met laagste inkomen:%  1.782864e-03
# 167                        In bezit woningcorporatie:%  1.744184e-03
# 202              Afstand tot oprit hoofdverkeersweg:km  1.682593e-03
# 39                                     tuinoppervlakte  1.679411e-03
# 165                               Percentage bewoond:%  1.674405e-03
# 41                                         tuinbreedte  1.666993e-03
# 171                         Niet-westers totaal:aantal  1.666881e-03
# 169                              Bouwjaar vanaf 2000:%  1.579231e-03
# 123                                  bathroom.badkamer  1.539342e-03
# 4                                           buurt_naam  1.528971e-03
# 145                   Afstand tot kinderdagverblijf:km  1.504535e-03
# 141                        Mate van stedelijkheid:code  1.490676e-03
# 212                                     startDayofyear  1.484848e-03
# 138                      Onderwerpen:Wijken en buurten  1.477884e-03
# 174                      Eenpersoonshuishoudens:aantal  1.457746e-03
# 45                               voorlopigenergielabel  1.425945e-03
# 46                                        energielabel  1.421573e-03
# 144                    Afstand tot grote supermarkt:km  1.405386e-03
# 199                              Oppervlakte totaal:ha  1.383997e-03
# 191                  Bedrijfsvestigingen totaal:aantal  1.382472e-03
# 61                                   gardenorientation  1.376481e-03
# 143                  Afstand tot huisartsenpraktijk:km  1.350638e-03
# 200                                Oppervlakte land:ha  1.347239e-03
# 126                                       municipality  1.347141e-03
# 140                                  Gemeentenaam:naam  1.340897e-03
# 122                                           bedrooms  1.149559e-03
# 209                                          startWeek  1.109683e-03
# 196     K-L Financiële diensten, onroerend goed:aantal  1.079625e-03
# 170                              Westers totaal:aantal  1.059858e-03
# 40                                          tuindiepte  1.025232e-03
# 201                               Oppervlakte water:ha  1.020843e-03
# 94                                             storage  9.870129e-04
# 146                              Afstand tot school:km  9.863223e-04
# 198    R-U Cultuur, recreatie, overige diensten:aantal  9.570286e-04
# 182                              15 tot 25 jaar:aantal  9.384647e-04
# 194                        G+I Handel en horeca:aantal  9.312171e-04
# 226                                     autoplekken_na  8.764492e-04
# 211                                     startDayofweek  8.741207e-04
# 181                               0 tot 15 jaar:aantal  8.697845e-04
# 195     H+J Vervoer, informatie en communicatie:aantal  8.542879e-04
# 189                                   Verweduwd:aantal  8.456701e-04
# 185                            65 jaar of ouder:aantal  8.407318e-04
# 183                              25 tot 45 jaar:aantal  7.970704e-04
# 92                                        roofmaterial  7.965647e-04
# 151           Personen per soort uitkering; AOW:aantal  7.936689e-04
# 91                                            rooftype  7.764986e-04
# 193                   B-F Nijverheid en energie:aantal  7.446141e-04
# 187                                      Gehuwd:aantal  7.154740e-04
# 38                                     housesubsubtype  7.146633e-04
# 7                                      bathroom.douche  7.084450e-04
# 173                              Sterfte totaal:aantal  6.989343e-04
# 95                        insulation.vollediggesoleerd  6.758272e-04
# 149            Personen per soort uitkering; AO:aantal  6.736868e-04
# 186                                    Ongehuwd:aantal  6.676511e-04
# 188                                  Gescheiden:aantal  6.538185e-04
# 77                                garage.parkeerkelder  6.433420e-04
# 184                              45 tot 65 jaar:aantal  6.415587e-04
# 172                             Geboorte totaal:aantal  5.912433e-04
# 176                    Huishoudens met kinderen:aantal  5.810777e-04
# 208                                         startMonth  5.794203e-04
# 148      Personen per soort uitkering; Bijstand:aantal  5.707575e-04
# 175                 Huishoudens zonder kinderen:aantal  5.478266e-04
# 162                              Woningvoorraad:aantal  5.468294e-04
# 230                                      lotsurface_na  5.407436e-04
# 229                                     livingspace_na  5.170238e-04
# 192             A Landbouw, bosbouw en visserij:aantal  4.905631e-04
# 8                                      bathroom.toilet  4.656963e-04
# 179                             Aantal inwoners:aantal  4.396754e-04
# 18                                     feature.elektra  4.221493e-04
# 150            Personen per soort uitkering; WW:aantal  3.986802e-04
# 6                                      bathroom.ligbad  3.858932e-04
# 124                             bathroom.aparte toilet  3.708037e-04
# 180                                      Mannen:aantal  3.688662e-04
# 222                                     tuinbreedte_na  3.516572e-04
# 100                  insulation.gedeeltelijkdubbelglas  3.505629e-04
# 221                                      tuindiepte_na  3.433584e-04
# 220                                 tuinoppervlakte_na  3.347119e-04
# 53                           orientation.aanrustigeweg  3.345697e-04
# 76                            parking.openbaarparkeren  3.259423e-04
# 50                            orientation.vrijuitzicht  3.126582e-04
# 99                               insulation.dubbelglas  3.111247e-04
# 78                                garage.parkeerplaats  2.941264e-04
# 206                                          startYear  2.919050e-04
# 51                              orientation.inwoonwijk  2.906668e-04
# 96                              insulation.dakisolatie  2.868484e-04
# 120                                     balcony.balkon  2.867541e-04
# 70                                  details.kluswoning  2.663048e-04
# 152                 Aantal inkomensontvangers  :aantal  2.424181e-04
# 207                                       startQuarter  2.400739e-04
# 62                         gardenaccessiblefromtherear  2.393154e-04
# 97                             insulation.muurisolatie  2.137132e-04
# 49                               orientation.incentrum  2.102023e-04
# 74                         parking.parkeervergunningen  1.977428e-04
# 48                                orientation.aanwater  1.900393e-04
# 93                                           soortbouw  1.749533e-04
# 24                               feature.stromendwater  1.677883e-04
# 98                            insulation.vloerisolatie  1.629792e-04
# 87                      garage.vrijstaandestenengarage  1.617129e-04
# 47                            orientation.aanvaarwater  1.598721e-04
# 135                                 constructionperiod  1.483162e-04
# 73                             parking.betaaldparkeren  1.444324e-04
# 117                                        autoplekken  1.390862e-04
# 14                                     feature.tvkabel  1.353756e-04
# 16                                        feature.lift  1.315602e-04
# 190          Indelingswijziging wijken en buurten:code  1.235832e-04
# 119                                  balcony.dakterras  1.208084e-04
# 58                      orientation.inbosrijkeomgeving  1.195941e-04
# 104                            insulation.geenisolatie  1.169171e-04
# 86                      garage.aangebouwdestenengarage  1.159279e-04
# 52                        orientation.beschutteligging  1.033753e-04
# 13                       feature.mechanischeventilatie  1.028184e-04
# 26                                  feature.verwarming  1.026968e-04
# 57                              orientation.aanbosrand  9.374513e-05
# 21                             feature.elektrischedeur  8.965212e-05
# 59                       orientation.buitenbebouwdekom  8.691492e-05
# 227                                        bedrooms_na  8.454000e-05
# 79                                     garage.inpandig  7.951734e-05
# 232                              yearofconstruction_na  7.711353e-05
# 67                details.beschermdstadsofdorpsgezicht  7.560678e-05
# 75                               parking.parkeergarage  6.851071e-05
# 56                                 orientation.aanpark  6.390317e-05
# 54                             orientation.openligging  5.833682e-05
# 69                                 details.gestoffeerd  5.727499e-05
# 19                                    feature.vliering  5.621328e-05
# 22                             feature.buitenzonwering  4.810375e-05
# 60                        orientation.landelijkgelegen  4.614446e-05
# 118                                balcony.fransbalkon  4.101345e-05
# 64                     details.gedeeltelijkgestoffeerd  3.981417e-05
# 15                                  feature.rookkanaal  3.885190e-05
# 55                            orientation.aandrukkeweg  3.729293e-05
# 84                                      garage.carport  3.405712e-05
# 17                                     feature.dakraam  3.364541e-05
# 30                              feature.glasvezelkabel  3.263636e-05
# 108                 certificate.giwwaarborgcertificaat  3.237324e-05
# 12                                bathroom.stoomcabine  3.075014e-05
# 23                                   feature.schuifpui  2.835819e-05
# 10                                      bathroom.sauna  2.593020e-05
# 63                                    details.monument  2.538427e-05
# 114                   certificate.ergieprestatieadvies  1.672853e-05
# 237                           Afstand tot school:km_na  1.541294e-05
# 27                            feature.alarminstallatie  1.490891e-05
# 261               Bedrijfsvestigingen totaal:aantal_na  1.432358e-05
# 213                                  startIs_month_end  1.337883e-05
# 66                     details.dubbelebewoningmogelijk  1.298898e-05
# 88                      garage.vrijstaandehoutengarage  1.291715e-05
# 106                 certificate.energieprestatieadvies  1.192781e-05
# 9                                     bathroom.jacuzzi  1.165782e-05
# 214                                startIs_month_start  1.155467e-05
# 102                               insulation.geenspouw  1.056453e-05
# 68                             details.monumentaalpand  1.056438e-05
# 32                                   feature.rolluiken  1.017034e-05
# 264                     G+I Handel en horeca:aantal_na  9.813838e-06
# 246              20% personen met hoogste inkomen:%_na  8.727024e-06
# 116                           certificate.huisgarantie  7.872134e-06
# 42                                 voortuinoppervlakte  7.653422e-06
# 252            Gemiddelde woningwaarde:x 1 000 euro_na  7.592662e-06
# 263                B-F Nijverheid en energie:aantal_na  7.590394e-06
# 81                                    garage.garagebox  7.242605e-06
# 259            Gemiddelde huishoudensgrootte:aantal_na  7.176595e-06
# 215                                startIs_quarter_end  6.896378e-06
# 270             Afstand tot treinstations totaal:km_na  6.443735e-06
# 89                             garage.garagemetcarport  6.192908e-06
# 248           40% huishoudens met laagste inkomen:%_na  5.910855e-06
# 267            M-N Zakelijke dienstverlening:aantal_na  5.902411e-06
# 115                     certificate.bouwkundigekeuring  5.851039e-06
# 244     Gemiddeld inkomen per inwoner :x 1 000 euro_na  5.614401e-06
# 82                                 garage.nietaanwezig  5.606797e-06
# 83                                  garage.welmogelijk  5.455649e-06
# 262          A Landbouw, bosbouw en visserij:aantal_na  5.353918e-06
# 245              40% personen met laagste inkomen:%_na  5.011645e-06
# 253                    Percentage eengezinswoning:%_na  4.649657e-06
# 25                             feature.airconditioning  4.599001e-06
# 265  H+J Vervoer, informatie en communicatie:aantal_na  4.482461e-06
# 250              Huishoudens met een laag inkomen:%_na  4.403991e-06
# 268  R-U Cultuur, recreatie, overige diensten:aanta...  4.185491e-06
# 101                            insulation.voorzetramen  4.115192e-06
# 251          Huish. onder of rond sociaal minimum:%_na  3.719586e-06
# 107                        certificate.politiekeurmerk  3.710574e-06
# 255                                  Koopwoningen:%_na  3.312358e-06
# 243  Gemiddeld inkomen per inkomensontvanger :x 1 0...  3.123937e-06
# 224                                  voortuindiepte_na  3.080830e-06
# 223                             voortuinoppervlakte_na  3.034775e-06
# 43                                      voortuindiepte  2.887998e-06
# 249           20% huishoudens met hoogste inkomen:%_na  2.838107e-06
# 80                               garage.garagemogelijk  2.532429e-06
# 247                           Actieven 15-75 jaar:%_na  2.322640e-06
# 266  K-L Financiële diensten, onroerend goed:aantal_na  1.997073e-06
# 239   Personen per soort uitkering; Bijstand:aantal_na  1.689283e-06
# 258                           Bouwjaar vanaf 2000:%_na  1.650651e-06
# 110                 certificate.swkgarantiecertificaat  1.280645e-06
# 217                                   startIs_year_end  1.225559e-06
# 225                                 voortuinbreedte_na  1.171276e-06
# 241         Personen per soort uitkering; WW:aantal_na  1.139944e-06
# 271       Afstand tot belangrijk overstapstation:km_na  1.030940e-06
# 44                                     voortuinbreedte  9.991287e-07
# 254                            Percentage bewoond:%_na  9.451436e-07
# 238                      Scholen binnen 3 km:aantal_na  7.464776e-07
# 20                            feature.zonnecollectoren  6.084692e-07
# 216                              startIs_quarter_start  6.049150e-07
# 28                                     feature.zwembad  5.127130e-07
# 256                     In bezit woningcorporatie:%_na  2.248142e-07
# 71                     details.dubbelebewoningaanwezig  2.018376e-07
# 234               Afstand tot huisartsenpraktijk:km_na  5.820938e-08
# 90                            garage.aangebouwdehouten  4.626595e-08
# 236                Afstand tot kinderdagverblijf:km_na  1.974565e-08
# 269           Afstand tot oprit hoofdverkeersweg:km_na  8.102595e-09
# 85                                   garage.souterrain  7.715524e-09
# 109          certificate.woningborggarantiecertificaat  3.143510e-09
# 260     Bevolkingsdichtheid:aantal inwoners per km²_na  0.000000e+00
# 273                                    startQuarter_na  0.000000e+00
# 274                                      startMonth_na  0.000000e+00
# 275                                       startWeek_na  0.000000e+00
# 276                                        startDay_na  0.000000e+00
# 277                                  startDayofweek_na  0.000000e+00
# 278                                  startDayofyear_na  0.000000e+00
# 272                                       startYear_na  0.000000e+00
# 72                        details.gedeeltelijkverhuurd  0.000000e+00
# 257                  In bezit overige verhuurders:%_na  0.000000e+00
# 242        Personen per soort uitkering; AOW:aantal_na  0.000000e+00
# 29                                       feature.sauna  0.000000e+00
# 31                                 feature.stoomcabine  0.000000e+00
# 33                                     feature.jacuzzi  0.000000e+00
# 34                            feature.satellietschotel  0.000000e+00
# 35                                   feature.windmolen  0.000000e+00
# 142                           Soort regio:omschrijving  0.000000e+00
# 65                                details.gemeubileerd  0.000000e+00
# 113                                       certificate.  0.000000e+00
# 112                        certificate.brandveiligheid  0.000000e+00
# 11                                     bathroom.zitbad  0.000000e+00
# 111                     certificate.algemenewoningkeur  0.000000e+00
# 105                certificate.kiwaveiligwonenkeurmerk  0.000000e+00
# 103                                 insulation.ecobouw  0.000000e+00
# 218                                 startIs_year_start  0.000000e+00
# 228                          bathroom.aparte toilet_na  0.000000e+00
# 231                                          volume_na  0.000000e+00
# 233                     Mate van stedelijkheid:code_na  0.000000e+00
# 235                 Afstand tot grote supermarkt:km_na  0.000000e+00
# 240         Personen per soort uitkering; AO:aantal_na  0.000000e+00
# 279                                    startElapsed_na  0.000000e+00

# %%
# We'll use an importance of 0.0025 as a threshold for whether or not to retain a column and retrain the model
# using only these columns

to_keep = fi[fi.imp>0.0025].cols

X_train_2 = X_train[to_keep].copy()
X_valid_2 = X_valid[to_keep].copy()

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_2, y_train)
print_score(m, X_train_2, y_train, X_valid_2, y_valid)
# Out:
# [0.09145014152522679, 0.19106193532897459, 0.9634206370549465, 0.8481187030189179, 0.8674574286053628]

# %% [markdown]
# **Analysis:** Our previous best scores for validation and oob were 0.8566466844028794 and 0.8636396442979561.  Thus you can see our model has improved slightly.  Our r^2 value on the training set has also decreased slightly, indicating that we are now overfitting slightly less to the training data.

# %% [markdown]
# **Feature Importance 2**
#
# now we examine FI for the simplified model.  Since we have likely removed alot of collinear columns, there is likely to be some change in the order of importance.

# %%
# original plot
plot_fi(fi[:23]);

# %%
# new plot  

fi2 = rf_feat_importance(m, X_train_2)
plot_fi(fi2);

# %% [markdown]
# **Analysis:** The order really didn't change all that much, and the relative importances seem more or less the same.  Let's examine now the correlation between these features.

# %% [markdown]
# **Hierarchical Cluster Analysis**

# %%
corr = np.round(scipy.stats.spearmanr(X_train_2).correlation, 4)
corr_condensed = hc.distance.squareform(1-corr)
z = hc.linkage(corr_condensed, method='average')
fig = plt.figure(figsize=(16,10))
dendrogram = hc.dendrogram(z, labels=X_train_2.columns, 
      orientation='left', leaf_font_size=16)
plt.show()

# %% [markdown]
# **Analysis:** A few things jump out.  postcode number part, V1.x and most common postcode are all identical, thus 2 of these 3 can be dropped.  There's also a very high correlation between average income per income recipient and 20% people with highest income, as well as average house worth and 20% households with highest income (confirming what we said earlier).  Livingspace and volume are also highly correlated.  We should drop one and see the effect on r^2.

# %%
m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_2.drop(['postcodenummerdeel','V1.x'],axis=1), y_train)
print_score(m, X_train_2.drop(['postcodenummerdeel','V1.x'],axis=1), y_train, X_valid_2.drop(['postcodenummerdeel','V1.x'],axis=1), y_valid)

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_2.drop(['postcodenummerdeel','Meest voorkomende postcode:code'],axis=1), y_train)
print_score(m, X_train_2.drop(['postcodenummerdeel','Meest voorkomende postcode:code'],axis=1), y_train, X_valid_2.drop(['postcodenummerdeel','Meest voorkomende postcode:code'],axis=1), y_valid)

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_2.drop(['V1.x','Meest voorkomende postcode:code'],axis=1), y_train)
print_score(m, X_train_2.drop(['V1.x','Meest voorkomende postcode:code'],axis=1), y_train, X_valid_2.drop(['V1.x','Meest voorkomende postcode:code'],axis=1), y_valid)

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_2.drop(['livingspace'],axis=1), y_train)
print_score(m, X_train_2.drop(['livingspace'],axis=1), y_train, X_valid_2.drop(['livingspace'],axis=1), y_valid)

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_2.drop(['volume'],axis=1), y_train)
print_score(m, X_train_2.drop(['volume'],axis=1), y_train, X_valid_2.drop(['volume'],axis=1), y_valid)
# Out:
# [0.09129017737210848, 0.1914669949673879, 0.9635484940294378, 0.8474740304239806, 0.867896754725286]
# [0.09170540101866842, 0.19185436416297239, 0.9632161483415448, 0.8468562359019346, 0.8667343839462395]
# [0.09149547107584323, 0.1910164563875269, 0.9633843651147985, 0.8481909997692649, 0.8678088088559244]
# [0.09462360699756821, 0.19638902575390504, 0.9608378639337057, 0.8395312818499819, 0.861159339853207]
# [0.09492912301796348, 0.19732928771795513, 0.9605845661406403, 0.8379910346204577, 0.8613729926647273]

# %% [markdown]
# **Analysis:** getting ride of the postcode duplicates doesn't seem to really affect r^2 all that much.  The combination of living space and volume was slighty more predictive than one vs. the other, so we'll keep both (for now)

# %%
X_train = X_train.drop(['postcodenummerdeel','Meest voorkomende postcode:code'], axis=1)
X_valid = X_valid.drop(['postcodenummerdeel','Meest voorkomende postcode:code'], axis=1)
X_test = X_test.drop(['postcodenummerdeel','Meest voorkomende postcode:code'], axis=1)

# %% [markdown]
# **Further Feature Removal**
#
# Next we'll find all features that have something to do with the amount of money people make or the value of homes and remove them from the dataset.  I had to translate the features in English in order to do this, but the subset listed below seems fairly comprehensive:
#
# - Aantal inkomensontvangers  :aantal
# - Gemiddeld inkomen per inkomensontvanger :x 1 000 euro
# - Gemiddeld inkomen per inwoner :x 1 000 euro
# - 40% personen met laagste inkomen:%
# - 20% personen met hoogste inkomen:%
# - 40% huishoudens met laagste inkomen:%
# - 20% huishoudens met hoogste inkomen:%
# - Huishoudens met een laag inkomen:%
# - Huish. onder of rond sociaal minimum:%
# - Gemiddelde woningwaarde:x 1 000 euro

# %%
print([col for col in X_train.columns if 'sociaal' in col])
# Out:
# ['Huish. onder of rond sociaal minimum:%', 'Huish. onder of rond sociaal minimum:%_na']

# %%
incomeset = set(['Aantal inkomensontvangers\xa0\xa0:aantal', 'Gemiddeld inkomen per inkomensontvanger\xa0:x 1 000 euro', 
                'Gemiddeld inkomen per inwoner\xa0:x 1 000 euro', '40% personen met laagste inkomen:%', 
                '20% personen met hoogste inkomen:%', '40% huishoudens met laagste inkomen:%', 
                '20% huishoudens met hoogste inkomen:%', 'Huishoudens met een laag inkomen:%', 
                'Gemiddelde woningwaarde:x 1 000 euro', 'Huish. onder of rond sociaal minimum:%'])

for income_column in incomeset:
    m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
    print(income_column," being kept: ")
    m.fit(X_train.drop(list(incomeset-set([income_column])),axis=1), y_train)
    print_score(m, X_train.drop(list(incomeset-set([income_column])),axis=1), y_train, X_valid.drop(list(incomeset-set([income_column])),axis=1), y_valid)
# Out:
# 40% personen met laagste inkomen:%  being kept:
# [0.08598082983325817, 0.1937761209278445, 0.9676651657910527, 0.8437728652865556, 0.8644700713606654]
# 40% huishoudens met laagste inkomen:%  being kept:
# [0.08583451309888693, 0.19397544691493257, 0.967775122901039, 0.8434512968323256, 0.8642979095587968]
# Gemiddeld inkomen per inkomensontvanger :x 1 000 euro  being kept:
# [0.08578805343159904, 0.19339768489177345, 0.9678099981937643, 0.8443824785456636, 0.8650589271373111]
# Huish. onder of rond sociaal minimum:%  being kept:
# [0.08605952028788894, 0.1936432288644975, 0.9676059524255127, 0.843987073591443, 0.864007754613307]
# Huishoudens met een laag inkomen:%  being kept:
# [0.08606014307855407, 0.1935549169358265, 0.9676054835689966, 0.844129342038348, 0.8643810496193474]
# 20% personen met hoogste inkomen:%  being kept:
# [0.08616170756407834, 0.19436362991082165, 0.9675289772162565, 0.842824100437449, 0.8641023162611253]
# Aantal inkomensontvangers  :aantal  being kept:
# [0.08620450185903462, 0.19355026230357042, 0.9674967141692784, 0.8441368387414038, 0.864161034571015]
# Gemiddelde woningwaarde:x 1 000 euro  being kept:
# [0.08483799399738043, 0.1909312610026089, 0.9685190263457002, 0.8483263864498674, 0.8682537833703715]
# 20% huishoudens met hoogste inkomen:%  being kept:
# [0.08624664037760542, 0.1942055866637628, 0.9674649298647907, 0.8430796059577061, 0.8640963766384113]
# Gemiddeld inkomen per inwoner :x 1 000 euro  being kept:
# [0.08606006005968672, 0.19254010479614028, 0.9676055460684225, 0.8457595229659176, 0.8647332192179441]

# %%
# we had to extract these due to special formatting characters that cannot be seen

to_drop = [col for col in X_train.columns if 'inkomen' in col] + \
[col for col in X_train.columns if (('woningwaarde' in col) & (col != 'Gemiddelde woningwaarde:x 1 000 euro'))] + \
[col for col in X_train.columns if 'sociaal' in col]

X_train = X_train.drop(to_drop, axis=1)
X_valid = X_valid.drop(to_drop, axis=1)
X_test = X_test.drop(to_drop, axis=1)

# %% [markdown]
# **Re-training the model and doing Feature Importance yet again...**

# %%
m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train, y_train)
print_score(m, X_train, y_train, X_valid, y_valid)
# Out:
# [0.08455411365459918, 0.19052564216270676, 0.9687293537521344, 0.8489701398698771, 0.8686003648680937]

# %%
fi3 = rf_feat_importance(m, X_train)

# %%
plot_fi(fi3[:30]);

# %%
X_train_3 = X_train[fi3[:30].cols.values]
X_valid_3 = X_valid[fi3[:30].cols.values]

corr = np.round(scipy.stats.spearmanr(X_train_3).correlation, 4)
corr_condensed = hc.distance.squareform(1-corr)
z = hc.linkage(corr_condensed, method='average')
fig = plt.figure(figsize=(16,10))
dendrogram = hc.dendrogram(z, labels=X_train_3.columns, 
      orientation='left', leaf_font_size=16)
plt.show()

# %% [markdown]
# **Analysis:** Finally, we are starting to see some more varied features. As with postcode, there are three columns here measuring exactly the same thing.  We should remove 2 of these 3

# %%
# baseline model

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_3, y_train)
print_score(m, X_train_3, y_train, X_valid_3, y_valid)
# Out:
# [0.0902891990931017, 0.18933545783761563, 0.9643434783217769, 0.8508511667417074, 0.8697130211606066]

# %%
m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_3.drop(['buurt_code','wijk_code'], axis=1), y_train)
print_score(m, X_train_3.drop(['buurt_code','wijk_code'], axis=1), y_train, X_valid_3.drop(['buurt_code','wijk_code'], axis=1), y_valid)

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_3.drop(['V1.y','wijk_code'], axis=1), y_train)
print_score(m, X_train_3.drop(['V1.y','wijk_code'], axis=1), y_train, X_valid_3.drop(['V1.y','wijk_code'], axis=1), y_valid)

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train_3.drop(['buurt_code','V1.y'], axis=1), y_train)
print_score(m, X_train_3.drop(['buurt_code','V1.y'], axis=1), y_train, X_valid_3.drop(['buurt_code','V1.y'], axis=1), y_valid)
# Out:
# [0.09047935949362139, 0.18990666295845693, 0.9641931259261314, 0.849949876620677, 0.8690044456580321]
# [0.09030294352097099, 0.18980904381835084, 0.9643326217454262, 0.8501040997431226, 0.8698539462428825]
# [0.09069365274549994, 0.19051160798041897, 0.9640233135362185, 0.8489923888700579, 0.8692409538348318]

# %% [markdown]
# **Analysis:** We should keep buurt_code

# %%
to_drop = ['wijk_code','V1.y']
X_train = X_train.drop(to_drop, axis=1)
X_valid = X_valid.drop(to_drop, axis=1)
X_test = X_test.drop(to_drop, axis=1)

# %%
m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train, y_train)
print_score(m, X_train, y_train, X_valid, y_valid)
# Out:
# [0.08512346754595165, 0.19110216091837703, 0.9683068076190103, 0.8480547430488807, 0.8677831462168728]

# %%
fi4 = rf_feat_importance(m, X_train)

# %%
plot_fi(fi4[:30]);

# %%
X_train_4 = X_train[fi4[:30].cols.values]
X_valid_4 = X_valid[fi4[:30].cols.values]

corr = np.round(scipy.stats.spearmanr(X_train_4).correlation, 4)
corr_condensed = hc.distance.squareform(1-corr)
z = hc.linkage(corr_condensed, method='average')
fig = plt.figure(figsize=(16,10))
dendrogram = hc.dendrogram(z, labels=X_train_4.columns, 
      orientation='left', leaf_font_size=16)
plt.show()

# %% [markdown]
# **Analysis:** What are some clusters we see here?  Going down the list from top to bottom, we observe the following clusters:
#
# - bedrooms and total rooms<br>
# - livingspace and volume<br>
# - longitude and V1.x (postcode) <br>
# - Non-westerners and people with an allowance benefit<br>
# - number of financial services and number of business services<br>
#
# The first and second are housing characteristics, the third is geographical location, the fourth a potential indicator of poverty, and the fifth indicates proximity to busines-heavy areas.  At this point there are two things we can do:
#
# 1) Inspect the categorical features more closely and see if it's possible to either create more features from them, or to eliminate them based on redundancy<br>
# 2) Experiment with dropping the semi-correlated features
#
# Let's start with the first.  For this we'll need to import the dataset from the first notebook, before we transformed the categories into machine learning friendly codes

# %%
houses = pickle.load(open('houses.p','rb'))

# %% [markdown]
# **Analysis:** To save space in the notebook, I haven't shown everything here.  The one important observation is that url is essentially a unique identifier for each home (the url from Funda for the listing) and doesn't have any information that we don't already have in other columns.  Thus, it can safely be deleted.

# %%
to_drop = ['url']
X_train = X_train.drop(to_drop, axis=1)
X_valid = X_valid.drop(to_drop, axis=1)
X_test = X_test.drop(to_drop, axis=1)

# %%
m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(X_train, y_train)
print_score(m, X_train, y_train, X_valid, y_valid)
# Out:
# [0.08517658702196648, 0.19067044735192254, 0.9682672403620564, 0.8487404782021134, 0.8678271283683718]

# %%
fi5 = rf_feat_importance(m, X_train)

# %%
plot_fi(fi5[:30]);

# %%
fi5[:30]
# Out:
#                                             cols       imp
# 125                                  livingspace  0.270490
# 127                                       volume  0.265062
# 149         Gemiddelde woningwaarde:x 1 000 euro  0.112413
# 34                                     housetype  0.049428
# 1                                           V1.x  0.035955
# 126                                   lotsurface  0.021665
# 133                           yearofconstruction  0.020392
# 35                                  housesubtype  0.018041
# 131                                    longitude  0.016760
# 130                                     latitude  0.013172
# 150                 Percentage eengezinswoning:%  0.008257
# 190    Afstand tot belangrijk overstapstation:km  0.007489
# 164  Bevolkingsdichtheid:aantal inwoners per km²  0.005984
# 142                   Scholen binnen 3 km:aantal  0.005791
# 0                                     buurt_code  0.005420
# 119                                        rooms  0.004961
# 123                                     province  0.004525
# 163         Gemiddelde huishoudensgrootte:aantal  0.003954
# 152                               Koopwoningen:%  0.003658
# 183         M-N Zakelijke dienstverlening:aantal  0.003386
# 205                                 startElapsed  0.003187
# 154               In bezit overige verhuurders:%  0.003186
# 191                            postcodealphadeel  0.002853
# 121                            bathroom.badkamer  0.002800
# 129                                      address  0.002786
# 147                        Actieven 15-75 jaar:%  0.002765
# 2                                        realtor  0.002710
# 189          Afstand tot treinstations totaal:km  0.002640
# 120                                     bedrooms  0.002495
# 128                                  housenumber  0.002431

# %%
top_2_train = X_train[fi5[:2].cols.values]
top_2_valid = X_valid[fi5[:2].cols.values]

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(top_2_train, y_train)
print_score(m, top_2_train, y_train, top_2_valid, y_valid)
# Out:
# [0.2627686056064365, 0.3278988082375767, 0.697994865394683, 0.5526621681878265, 0.5835245824996285]

# %%
top_4_train = X_train[fi5[:4].cols.values]
top_4_valid = X_valid[fi5[:4].cols.values]

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(top_4_train, y_train)
print_score(m, top_4_train, y_train, top_4_valid, y_valid)
# Out:
# [0.17380889193277366, 0.2621510022202712, 0.8678669817242081, 0.7140704789435386, 0.7414612294381224]

# %%
top_8_train = X_train[fi5[:8].cols.values]
top_8_valid = X_valid[fi5[:8].cols.values]

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(top_8_train, y_train)
print_score(m, top_8_train, y_train, top_8_valid, y_valid)
# Out:
# [0.11561107752532272, 0.20749377338924155, 0.9415389957122988, 0.8208709225017515, 0.8408519703254757]

# %%
top_10_train = X_train[fi5[:10].cols.values]
top_10_valid = X_valid[fi5[:10].cols.values]

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(top_10_train, y_train)
print_score(m, top_10_train, y_train, top_10_valid, y_valid)
# Out:
# [0.10505239886513867, 0.1967057912115732, 0.9517297751616415, 0.8390132086978778, 0.8581518842630411]

# %%
_train = X_train[fi5[:25].cols.values]
_valid = X_valid[fi5[:25].cols.values]

m = RFR(n_estimators=80, min_samples_leaf=3, max_features=0.5, n_jobs=-1, oob_score=True)
m.fit(_train, y_train)
print_score(m, _train, y_train, _valid, y_valid)
# Out:
# [0.09159934946344367, 0.18936997514602355, 0.9633011755920653, 0.8507967798285032, 0.8700252546792939]

# %%
X_train_5 = X_train[fi5[:30].cols.values]
X_valid_5 = X_valid[fi5[:30].cols.values]

corr = np.round(scipy.stats.spearmanr(top_10_train).correlation, 4)
corr_condensed = hc.distance.squareform(1-corr)
z = hc.linkage(corr_condensed, method='average')
fig = plt.figure(figsize=(16,20))
dendrogram = hc.dendrogram(z, labels=top_10_train.columns, 
      orientation='left', leaf_font_size=16)
plt.show()

# %%
fi5[:10]
# Out:
#                                      cols       imp
# 125                           livingspace  0.270490
# 127                                volume  0.265062
# 149  Gemiddelde woningwaarde:x 1 000 euro  0.112413
# 34                              housetype  0.049428
# 1                                    V1.x  0.035955
# 126                            lotsurface  0.021665
# 133                    yearofconstruction  0.020392
# 35                           housesubtype  0.018041
# 131                             longitude  0.016760
# 130                              latitude  0.013172

# %% [markdown]
# **Final Analysis:** It appears we have made all the improvements we can for now.  We'll serialize the datasets and do some more intensive fine-tuning in a separate notebook

# %%
houses_final = houses[top_10_train.columns]
houses_final.rename(index=str, columns={'V1.x':'postcode5'})
# Out:
#        livingspace  volume  Gemiddelde woningwaarde:x 1 000 euro  \
# 57585         97.0   255.0                                 270.0
# 57584        106.0   264.0                                 270.0
# 50443         82.0   213.0                                 171.0
# 74786          NaN   480.0                                 149.0
# 57583        127.0   335.0                                 270.0
# 73693          NaN   254.0                                 217.0
# 75968        130.0   444.0                                 211.0
# 75963        130.0   444.0                                 211.0
# 75965        130.0   444.0                                 211.0
# 75964        130.0   444.0                                 211.0
# 75967        130.0   444.0                                 211.0
# 47205          NaN   225.0                                 140.0
# 75966        130.0   444.0                                 211.0
# 9580         110.0   350.0                                 183.0
# 25555        125.0   350.0                                 252.0
# 72491          NaN   280.0                                 159.0
# 49594         75.0   225.0                                 174.0
# 33422          NaN   387.0                                 430.0
# 3105         140.0   362.0                                 113.0
# 74759          NaN   380.0                                 183.0
# 7722          85.0   220.0                                 181.0
# 2641         100.0   300.0                                 140.0
# 70722        150.0   375.0                                 183.0
# 50848          NaN   400.0                                 214.0
# 78656        103.0   370.0                                 282.0
# 69081          NaN   344.0                                 169.0
# 3146         127.0   393.0                                 127.0
# 14636         90.0   270.0                                 165.0
# 19374        110.0   600.0                                 294.0
# 11243        102.0   335.0                                 173.0
# ...            ...     ...                                   ...
# 78779        133.0   433.0                                 152.0
# 66238          NaN   300.0                                 130.0
# 26890          NaN   325.0                                 305.0
# 41342        140.0   420.0                                 216.0
# 67611        110.0   380.0                                 295.0
# 73977        109.0   330.0                                 233.0
# 23473         85.0   312.0                                 194.0
# 19628        104.0   385.0                                 159.0
# 44445        131.0   409.0                                 154.0
# 28697        108.0   374.0                                 229.0
# 43388         95.0   295.0                                 159.0
# 62220        150.0   552.0                                 234.0
# 77542        137.0   528.0                                 236.0
# 26172        104.0   413.0                                 228.0
# 65003          NaN   354.0                                 196.0
# 53978        120.0   450.0                                   NaN
# 2818         151.0   362.0                                 206.0
# 49161         92.0   281.0                                 130.0
# 58454        180.0   810.0                                 243.0
# 63028        145.0   530.0                                   NaN
# 12017         89.0   270.0                                 183.0
# 26044        110.0   432.0                                 248.0
# 5307         120.0   375.0                                 166.0
# 4326          60.0   170.0                                 117.0
# 13375         83.0   340.0                                 185.0
# 25395        165.0   714.0                                 461.0
# 25396        165.0   714.0                                 461.0
# 25397        161.0   698.0                                 461.0
# 38372        105.0   305.0                                 231.0
# 43850        109.0   332.0                                 181.0
#
#              housetype  postcode5  lotsurface  yearofconstruction  \
# 57585      appartement      48990         NaN              2013.0
# 57584      appartement      48989         NaN              2013.0
# 50443      appartement      42289         NaN              2011.0
# 74786  eengezinswoning      59549         NaN              1987.0
# 57583      appartement      48988         NaN              2013.0
# 73693  eengezinswoning      22013         NaN              1954.0
# 75968  eengezinswoning      79127         NaN              2014.0
# 75963  eengezinswoning      79122         NaN              2014.0
# 75965  eengezinswoning      79124         NaN              2014.0
# 75964  eengezinswoning      79123         NaN              2014.0
# 75967  eengezinswoning      79126         NaN              2014.0
# 47205      appartement      28337         NaN              1963.0
# 75966  eengezinswoning      79125         NaN              2014.0
# 9580         herenhuis      71514       210.0              1981.0
# 25555  eengezinswoning      39596       248.0              1970.0
# 72491         bungalow      82056         NaN              1966.0
# 49594      appartement      22378         NaN              1962.0
# 33422  eengezinswoning      10855         NaN              1960.0
# 3105          bungalow      83016      1130.0              1985.0
# 74759  eengezinswoning      59492         NaN              1971.0
# 7722       appartement      72337         NaN              1991.0
# 2641   eengezinswoning       6097       379.0              2005.0
# 70722  eengezinswoning      65427       142.0              1976.0
# 50848  eengezinswoning      42997         NaN              2015.0
# 78656  eengezinswoning      67025         NaN              2014.0
# 69081  eengezinswoning      42101         NaN              2015.0
# 3146   eengezinswoning      82961       445.0              1974.0
# 14636  eengezinswoning      40954       153.0              1953.0
# 19374    woonboerderij      69409      4600.0                 NaN
# 11243  eengezinswoning      75075        72.0                 NaN
# ...                ...        ...         ...                 ...
# 78779  eengezinswoning      83079      1023.0              1965.0
# 66238  eengezinswoning      76603         NaN              1982.0
# 26890  eengezinswoning       7280         NaN              2005.0
# 41342  eengezinswoning      24607       126.0              1975.0
# 67611  eengezinswoning      21676       108.0              2005.0
# 73977  eengezinswoning      22037       130.0              1968.0
# 23473  eengezinswoning      34404       109.0              1946.0
# 19628  eengezinswoning      66140       138.0              1982.0
# 44445      appartement      26168         NaN              1939.0
# 28697  eengezinswoning      11761       130.0              1958.0
# 43388      appartement      32230         NaN              2007.0
# 62220  eengezinswoning      49627       255.0              2014.0
# 77542        herenhuis      21402       200.0              1998.0
# 26172  eengezinswoning      35890       128.0              1980.0
# 65003  eengezinswoning      57344         NaN              1953.0
# 53978  eengezinswoning      83111      1002.0              1921.0
# 2818   eengezinswoning       6482       105.0              2015.0
# 49161      appartement      22479         NaN              1972.0
# 58454  eengezinswoning      46573       634.0              1976.0
# 63028  eengezinswoning      57806     16754.0              1969.0
# 12017      appartement      67276         NaN              2000.0
# 26044  eengezinswoning      35954       400.0              1920.0
# 5307   eengezinswoning      80661       160.0                 NaN
# 4326       appartement      79557         NaN              1980.0
# 13375  eengezinswoning      64676       204.0              1952.0
# 25395        herenhuis      39218         NaN              2017.0
# 25396        herenhuis      39219         NaN              2017.0
# 25397        herenhuis      39220         NaN              2017.0
# 38372      appartement      20160         NaN              2000.0
# 43850      appartement      25557         NaN              1985.0
#
#                  housesubtype  longitude   latitude
# 57585             portiekflat   5.132951  51.484440
# 57584             portiekflat   5.132951  51.484440
# 50443             galerijflat   3.617541  51.497042
# 74786  halfvrijstaande woning   5.835048  50.979161
# 57583             portiekflat   5.132951  51.484440
# 73693              hoekwoning   4.214098  51.960720
# 75968              hoekwoning   5.627355  53.040674
# 75963            tussenwoning   5.627355  53.040674
# 75965              hoekwoning   5.627355  53.040674
# 75964            tussenwoning   5.627355  53.040674
# 75967              hoekwoning   5.627355  53.040674
# 47205             galerijflat   4.399894  51.924523
# 75966              hoekwoning   5.627355  53.040674
# 9580               hoekwoning   6.834307  52.286665
# 25555            tussenwoning   5.409068  52.084499
# 72491      vrijstaande woning   6.480762  52.978893
# 49594             galerijflat   4.504439  52.048851
# 33422            tussenwoning   4.749660  53.024040
# 3105       vrijstaande woning   6.888299  53.111436
# 74759     2-onder-1-kapwoning   5.832582  51.012214
# 7722              galerijflat   6.755780  52.300369
# 2641             tussenwoning   5.289059  52.397849
# 70722              hoekwoning   5.931408  51.948800
# 50848            tussenwoning   4.077566  51.443106
# 78656     2-onder-1-kapwoning   6.182844  51.903039
# 69081            tussenwoning   3.916507  51.651984
# 3146   halfvrijstaande woning   6.857116  53.093763
# 14636            tussenwoning   5.221796  51.950775
# 19374      vrijstaande woning   6.105535  52.268538
# 11243            tussenwoning   6.111360  52.514727
# ...                       ...        ...        ...
# 78779      vrijstaande woning   6.920850  53.138981
# 66238              eindwoning   5.500267  52.501306
# 26890              eindwoning   4.800019  52.278847
# 41342            tussenwoning   4.620872  51.915721
# 67611            tussenwoning   4.458535  51.985749
# 73977            tussenwoning   4.250154  51.978835
# 23473            tussenwoning   5.082996  52.098433
# 19628            tussenwoning   5.976680  51.951200
# 44445             bovenwoning   4.459333  51.929673
# 28697            tussenwoning   4.661290  52.554421
# 43388             galerijflat   4.684137  51.826275
# 62220     2-onder-1-kapwoning   5.040162  51.671806
# 77542     2-onder-1-kapwoning   4.437051  52.014785
# 26172            tussenwoning   5.217849  52.091164
# 65003            tussenwoning   6.179144  51.368527
# 53978      vrijstaande woning   6.940208  53.068026
# 2818               hoekwoning   5.159098  52.356658
# 49161             galerijflat   4.471950  52.057265
# 58454      vrijstaande woning   4.855866  51.592423
# 63028      vrijstaande woning   6.054489  51.263316
# 12017           benedenwoning   6.484770  51.867032
# 26044     2-onder-1-kapwoning   5.243063  52.094832
# 5307       geschakelde woning   6.069877  53.096811
# 4326            portiekwoning   5.799495  53.203707
# 13375            tussenwoning   5.930333  52.003468
# 25395     2-onder-1-kapwoning   5.537380  52.012096
# 25396     2-onder-1-kapwoning   5.537380  52.012096
# 25397     2-onder-1-kapwoning   5.537380  52.012096
# 38372             portiekflat   4.275219  52.086179
# 43850             maisonnette   4.491348  51.921303
#
# [78295 rows x 10 columns]

# %%
houses_final.head()
# Out:
#        livingspace  volume  Gemiddelde woningwaarde:x 1 000 euro  \
# 57585         97.0   255.0                                 270.0
# 57584        106.0   264.0                                 270.0
# 50443         82.0   213.0                                 171.0
# 74786          NaN   480.0                                 149.0
# 57583        127.0   335.0                                 270.0
#
#              housetype   V1.x  lotsurface  yearofconstruction  \
# 57585      appartement  48990         NaN              2013.0
# 57584      appartement  48989         NaN              2013.0
# 50443      appartement  42289         NaN              2011.0
# 74786  eengezinswoning  59549         NaN              1987.0
# 57583      appartement  48988         NaN              2013.0
#
#                  housesubtype  longitude   latitude
# 57585             portiekflat   5.132951  51.484440
# 57584             portiekflat   5.132951  51.484440
# 50443             galerijflat   3.617541  51.497042
# 74786  halfvrijstaande woning   5.835048  50.979161
# 57583             portiekflat   5.132951  51.484440

# %%
top_10_test = X_test[top_10_train.columns]

# %%
pickle.dump([top_10_train, y_train], open('train_final.p','wb'))
pickle.dump([top_10_valid, y_valid], open('valid_final.p','wb'))
pickle.dump([top_10_test, y_test], open('test_final.p','wb'))

# %%
pickle.dump(houses_final, open('houses_final.p','wb'))
