# %% [markdown]
# **All steps related to data cleaning for assignment 2**

# %%
import pandas as pd
import numpy as np
import re
import math
import pickle
import matplotlib.pyplot as plt

from sklearn import metrics
from preprocessing import *
from sklearn.ensemble import RandomForestRegressor as RFR

# %% [markdown]
# **Import & Sort by sale date**

# %%
houses = pd.read_csv('../Data/houses-preprocessed-buurten.csv', encoding='latin-1', parse_dates=['startdate','enddate'])
houses.sort_values(['enddate'], ascending=[True], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-e5084d52277c> in <module>()
# ----> 1 houses = pd.read_csv('../Data/houses-preprocessed-buurten.csv', encoding='latin-1', parse_dates=['startdate','enddate'])
#       2 houses.sort_values(['enddate'], ascending=[True], inplace=True)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'../Data/houses-preprocessed-buurten.csv' does not exist

# %% [markdown]
# **Drop unneeded or unwanted columns**

# %%
houses = houses.drop(['Unnamed: 0'], axis=1)
# Next we drop the duration column to prevent data leakage (we won't know these things beforehand)
# Later, we'll also drop enddate but for now we want to keep for sorting
houses = houses.drop(['duration'], axis=1)
houses = houses.drop(houses[houses.endprice.isnull()].index) # drop rows where the target column is null
# Finally, we also drop the startprice column, but first, we store the index of all rows where the end price
# was not equal to the start price
price_change_index = houses[houses.startprice != houses.endprice].index
houses = houses.drop(['startprice'], axis=1)

# %% [markdown]
# **Inspect the dataset for numericals that should be categorized**

# %%
display_all(houses.dtypes)
# Out:
# buurt_code                                                       object
# V1.x                                                              int64
# endprice                                                        float64
# url                                                              object
# realtor                                                          object
# buurt_naam                                                       object
# wijk_code                                                        object
# bathroom.ligbad                                                   int64
# bathroom.douche                                                   int64
# bathroom.toilet                                                   int64
# bathroom.jacuzzi                                                  int64
# bathroom.sauna                                                    int64
# bathroom.zitbad                                                   int64
# bathroom.stoomcabine                                              int64
# feature.mechanischeventilatie                                      bool
# feature.tvkabel                                                    bool
# feature.rookkanaal                                                 bool
# feature.lift                                                       bool
# feature.dakraam                                                    bool
# feature.elektra                                                    bool
# feature.vliering                                                   bool
# feature.zonnecollectoren                                           bool
# feature.elektrischedeur                                            bool
# feature.buitenzonwering                                            bool
# feature.schuifpui                                                  bool
# feature.stromendwater                                              bool
# feature.airconditioning                                            bool
# feature.verwarming                                                 bool
# feature.alarminstallatie                                           bool
# feature.zwembad                                                    bool
# feature.sauna                                                      bool
# feature.glasvezelkabel                                             bool
# feature.stoomcabine                                                bool
# feature.rolluiken                                                  bool
# feature.jacuzzi                                                    bool
# feature.satellietschotel                                           bool
# feature.windmolen                                                  bool
# housetype                                                        object
# housesubtype                                                     object
# housesubsubtype                                                  object
# tuinoppervlakte                                                 float64
# tuindiepte                                                      float64
# tuinbreedte                                                     float64
# voortuinoppervlakte                                             float64
# voortuindiepte                                                  float64
# voortuinbreedte                                                 float64
# voorlopigenergielabel                                            object
# energielabel                                                     object
# orientation.aanvaarwater                                           bool
# orientation.aanwater                                               bool
# orientation.incentrum                                              bool
# orientation.vrijuitzicht                                           bool
# orientation.inwoonwijk                                             bool
# orientation.beschutteligging                                       bool
# orientation.aanrustigeweg                                          bool
# orientation.openligging                                            bool
# orientation.aandrukkeweg                                           bool
# orientation.aanpark                                                bool
# orientation.aanbosrand                                             bool
# orientation.inbosrijkeomgeving                                     bool
# orientation.buitenbebouwdekom                                      bool
# orientation.landelijkgelegen                                       bool
# gardenorientation                                                object
# gardenaccessiblefromtherear                                        bool
# details.monument                                                   bool
# details.gedeeltelijkgestoffeerd                                    bool
# details.gemeubileerd                                               bool
# details.dubbelebewoningmogelijk                                    bool
# details.beschermdstadsofdorpsgezicht                               bool
# details.monumentaalpand                                            bool
# details.gestoffeerd                                                bool
# details.kluswoning                                                 bool
# details.dubbelebewoningaanwezig                                    bool
# details.gedeeltelijkverhuurd                                       bool
# parking.betaaldparkeren                                            bool
# parking.parkeervergunningen                                        bool
# parking.parkeergarage                                              bool
# parking.openbaarparkeren                                           bool
# garage.parkeerkelder                                               bool
# garage.parkeerplaats                                               bool
# garage.inpandig                                                    bool
# garage.garagemogelijk                                              bool
# garage.garagebox                                                   bool
# garage.nietaanwezig                                                bool
# garage.welmogelijk                                                 bool
# garage.carport                                                     bool
# garage.souterrain                                                  bool
# garage.aangebouwdestenengarage                                     bool
# garage.vrijstaandestenengarage                                     bool
# garage.vrijstaandehoutengarage                                     bool
# garage.garagemetcarport                                            bool
# garage.aangebouwdehouten                                           bool
# rooftype                                                         object
# roofmaterial                                                     object
# soortbouw                                                        object
# storage                                                          object
# insulation.vollediggesoleerd                                       bool
# insulation.dakisolatie                                             bool
# insulation.muurisolatie                                            bool
# insulation.vloerisolatie                                           bool
# insulation.dubbelglas                                              bool
# insulation.gedeeltelijkdubbelglas                                  bool
# insulation.voorzetramen                                            bool
# insulation.geenspouw                                               bool
# insulation.ecobouw                                                 bool
# insulation.geenisolatie                                            bool
# certificate.kiwaveiligwonenkeurmerk                                bool
# certificate.energieprestatieadvies                                 bool
# certificate.politiekeurmerk                                        bool
# certificate.giwwaarborgcertificaat                                 bool
# certificate.woningborggarantiecertificaat                          bool
# certificate.swkgarantiecertificaat                                 bool
# certificate.algemenewoningkeur                                     bool
# certificate.brandveiligheid                                        bool
# certificate.                                                       bool
# certificate.ergieprestatieadvies                                   bool
# certificate.bouwkundigekeuring                                     bool
# certificate.huisgarantie                                           bool
# autoplekken                                                     float64
# balcony.fransbalkon                                                bool
# balcony.dakterras                                                  bool
# balcony.balkon                                                     bool
# rooms                                                           float64
# bedrooms                                                        float64
# bathroom.badkamer                                                 int64
# bathroom.aparte toilet                                            int64
# province                                                         object
# municipality                                                     object
# postcode                                                         object
# livingspace                                                     float64
# lotsurface                                                      float64
# volume                                                          float64
# housenumber                                                       int64
# postcodenummerdeel                                                int64
# address                                                          object
# startdate                                                datetime64[ns]
# enddate                                                  datetime64[ns]
# latitude                                                        float64
# longitude                                                       float64
# constructionperiod                                               object
# yearofconstruction                                              float64
# V1.y                                                              int64
# Onderwerpen:Wijken en buurten                                    object
# Meest voorkomende postcode:code                                 float64
# Gemeentenaam:naam                                                object
# Mate van stedelijkheid:code                                     float64
# Soort regio:omschrijving                                         object
# Afstand tot huisartsenpraktijk:km                               float64
# Afstand tot grote supermarkt:km                                 float64
# Afstand tot kinderdagverblijf:km                                float64
# Afstand tot school:km                                           float64
# Scholen binnen 3 km:aantal                                      float64
# Personen per soort uitkering; Bijstand:aantal                   float64
# Personen per soort uitkering; AO:aantal                         float64
# Personen per soort uitkering; WW:aantal                         float64
# Personen per soort uitkering; AOW:aantal                        float64
# Aantal inkomensontvangers  :aantal                                int64
# Gemiddeld inkomen per inkomensontvanger :x 1 000 euro           float64
# Gemiddeld inkomen per inwoner :x 1 000 euro                     float64
# 40% personen met laagste inkomen:%                              float64
# 20% personen met hoogste inkomen:%                              float64
# Actieven 15-75 jaar:%                                           float64
# 40% huishoudens met laagste inkomen:%                           float64
# 20% huishoudens met hoogste inkomen:%                           float64
# Huishoudens met een laag inkomen:%                              float64
# Huish. onder of rond sociaal minimum:%                          float64
# Woningvoorraad:aantal                                             int64
# Gemiddelde woningwaarde:x 1 000 euro                            float64
# Percentage eengezinswoning:%                                    float64
# Percentage bewoond:%                                            float64
# Koopwoningen:%                                                  float64
# In bezit woningcorporatie:%                                     float64
# In bezit overige verhuurders:%                                  float64
# Bouwjaar vanaf 2000:%                                           float64
# Westers totaal:aantal                                             int64
# Niet-westers totaal:aantal                                        int64
# Geboorte totaal:aantal                                            int64
# Sterfte totaal:aantal                                             int64
# Eenpersoonshuishoudens:aantal                                     int64
# Huishoudens zonder kinderen:aantal                                int64
# Huishoudens met kinderen:aantal                                   int64
# Gemiddelde huishoudensgrootte:aantal                            float64
# Bevolkingsdichtheid:aantal inwoners per km²                     float64
# Aantal inwoners:aantal                                            int64
# Mannen:aantal                                                     int64
# 0 tot 15 jaar:aantal                                              int64
# 15 tot 25 jaar:aantal                                             int64
# 25 tot 45 jaar:aantal                                             int64
# 45 tot 65 jaar:aantal                                             int64
# 65 jaar of ouder:aantal                                           int64
# Ongehuwd:aantal                                                   int64
# Gehuwd:aantal                                                     int64
# Gescheiden:aantal                                                 int64
# Verweduwd:aantal                                                  int64
# Indelingswijziging wijken en buurten:code                         int64
# Bedrijfsvestigingen totaal:aantal                               float64
# A Landbouw, bosbouw en visserij:aantal                          float64
# B-F Nijverheid en energie:aantal                                float64
# G+I Handel en horeca:aantal                                     float64
# H+J Vervoer, informatie en communicatie:aantal                  float64
# K-L Financiële diensten, onroerend goed:aantal                  float64
# M-N Zakelijke dienstverlening:aantal                            float64
# R-U Cultuur, recreatie, overige diensten:aantal                 float64
# Oppervlakte totaal:ha                                             int64
# Oppervlakte land:ha                                               int64
# Oppervlakte water:ha                                              int64
# Afstand tot oprit hoofdverkeersweg:km                           float64
# Afstand tot treinstations totaal:km                             float64
# Afstand tot belangrijk overstapstation:km                       float64
# dtype: object

# %%
houses['housenumber'] = houses['housenumber'].apply(lambda x: str(x))
houses['postcodealphadeel'] = houses['postcode'].apply(lambda x: x[4:])
houses['postcodenummerdeel'] = houses['postcodenummerdeel'].apply(lambda x: str(x))
houses['Meest voorkomende postcode:code'] = houses['Meest voorkomende postcode:code'].apply(lambda x: str(x))

houses = houses.drop(['postcode'],axis=1) # drop as it's no longer needed

# %% [markdown]
# **Inspect for suspicious values and set to null**

# %%
# We are looking for things like values with 9999... or negative values where they don't make sense
display_all(houses.describe())
# Out:
#                V1.x      endprice  bathroom.ligbad  bathroom.douche  \
# count  78295.000000  7.829500e+04     78295.000000     78295.000000
# mean   44656.622454  2.792229e+05         0.342423         0.637257
# std    23378.673600  1.754763e+05         0.475867         0.567248
# min       40.000000  5.500000e+03         0.000000         0.000000
# 25%    24635.500000  1.750000e+05         0.000000         0.000000
# 50%    44877.000000  2.390000e+05         0.000000         1.000000
# 75%    64781.500000  3.250000e+05         1.000000         1.000000
# max    85188.000000  1.100000e+07         2.000000         6.000000
#
#        bathroom.toilet  bathroom.jacuzzi  bathroom.sauna  bathroom.zitbad  \
# count      78295.00000      78295.000000    78295.000000     78295.000000
# mean           0.46358          0.006705        0.008238         0.003717
# std            0.55928          0.081612        0.090390         0.060852
# min            0.00000          0.000000        0.000000         0.000000
# 25%            0.00000          0.000000        0.000000         0.000000
# 50%            0.00000          0.000000        0.000000         0.000000
# 75%            1.00000          0.000000        0.000000         0.000000
# max            6.00000          1.000000        1.000000         1.000000
#
#        bathroom.stoomcabine  tuinoppervlakte    tuindiepte   tuinbreedte  \
# count          78295.000000     42555.000000  43397.000000  43397.000000
# mean               0.004317       102.958722     12.862535      8.292296
# std                0.065757       105.498332     18.645757     15.782514
# min                0.000000         1.000000      0.010000      0.010000
# 25%                0.000000        50.000000      8.730000      5.250000
# 50%                0.000000        72.000000     11.000000      6.000000
# 75%                0.000000       112.000000     14.000000      9.100000
# max                2.000000       999.000000   1700.000000   1500.000000
#
#        voortuinoppervlakte  voortuindiepte  voortuinbreedte   autoplekken  \
# count           826.000000      850.000000       850.000000  22159.000000
# mean             97.793908       10.619294         8.870318      1.327000
# std             130.287018       12.015181         7.553481      1.562989
# min               1.000000        0.010000         0.010000      1.000000
# 25%              27.000000        5.000000         5.000000      1.000000
# 50%              53.000000        8.000000         6.300000      1.000000
# 75%             100.750000       12.000000        10.000000      1.000000
# max             950.000000      140.000000        70.000000     99.000000
#
#               rooms      bedrooms  bathroom.badkamer  bathroom.aparte toilet  \
# count  78295.000000  77309.000000       78295.000000            78295.000000
# mean       4.701054      3.265364           0.747711                0.815889
# std        1.599610      1.151603           0.593468                0.577185
# min        1.000000      0.000000           0.000000                0.000000
# 25%        4.000000      2.000000           0.000000                0.000000
# 50%        5.000000      3.000000           1.000000                1.000000
# 75%        5.000000      4.000000           1.000000                1.000000
# max       78.000000      9.000000           6.000000                9.000000
#
#         livingspace     lotsurface        volume      latitude     longitude  \
# count  73720.000000   53355.000000  78246.000000  78295.000000  78295.000000
# mean     121.304910     604.377584    416.200074     52.083268      5.308028
# std       50.363555    5016.994578    230.014239      0.510262      0.771909
# min       17.000000      12.000000     57.000000     50.762268      3.378399
# 25%       90.000000     145.500000    290.000000     51.796032      4.654870
# 50%      115.000000     215.000000    375.000000     52.048851      5.245811
# 75%      140.000000     373.000000    480.000000     52.345333      5.893551
# max     1632.000000  999999.000000   9000.000000     53.481699      7.210440
#
#        yearofconstruction          V1.y  Mate van stedelijkheid:code  \
# count        74006.000000  78295.000000                 78261.000000
# mean          1972.320663   5896.131107                     2.845594
# std             36.424820   3202.649663                     1.354674
# min           1180.000000      1.000000                     1.000000
# 25%           1959.000000   3326.000000                     2.000000
# 50%           1978.000000   6027.000000                     3.000000
# 75%           1998.000000   8376.000000                     4.000000
# max           2020.000000  12233.000000                     5.000000
#
#        Afstand tot huisartsenpraktijk:km  Afstand tot grote supermarkt:km  \
# count                       77941.000000                     77941.000000
# mean                            0.981802                         0.899541
# std                             0.818008                         0.783668
# min                             0.100000                         0.100000
# 25%                             0.500000                         0.500000
# 50%                             0.700000                         0.700000
# 75%                             1.100000                         1.000000
# max                            11.900000                        11.700000
#
#        Afstand tot kinderdagverblijf:km  Afstand tot school:km  \
# count                      77941.000000           77448.000000
# mean                           0.850364               0.686047
# std                            0.839133               0.481313
# min                            0.100000               0.100000
# 25%                            0.400000               0.400000
# 50%                            0.600000               0.600000
# 75%                            0.900000               0.700000
# max                           12.700000              10.300000
#
#        Scholen binnen 3 km:aantal  \
# count                77448.000000
# mean                    10.685802
# std                      8.753115
# min                      0.000000
# 25%                      4.800000
# 50%                      8.900000
# 75%                     14.000000
# max                     62.400000
#
#        Personen per soort uitkering; Bijstand:aantal  \
# count                                   77533.000000
# mean                                      101.719526
# std                                       188.601115
# min                                         0.000000
# 25%                                        10.000000
# 50%                                        50.000000
# 75%                                       110.000000
# max                                      1890.000000
#
#        Personen per soort uitkering; AO:aantal  \
# count                             77533.000000
# mean                                162.718068
# std                                 157.609705
# min                                   0.000000
# 25%                                  50.000000
# 50%                                 120.000000
# 75%                                 220.000000
# max                                1280.000000
#
#        Personen per soort uitkering; WW:aantal  \
# count                             77533.000000
# mean                                 95.606774
# std                                  92.610229
# min                                   0.000000
# 25%                                  30.000000
# 50%                                  70.000000
# 75%                                 130.000000
# max                                 750.000000
#
#        Personen per soort uitkering; AOW:aantal  \
# count                              77533.000000
# mean                                 637.582836
# std                                  660.028393
# min                                    0.000000
# 25%                                  210.000000
# 50%                                  450.000000
# 75%                                  850.000000
# max                                 7490.000000
#
#        Aantal inkomensontvangers  :aantal  \
# count                        78295.000000
# mean                          2792.530813
# std                           2524.276318
# min                              0.000000
# 25%                           1100.000000
# 50%                           2100.000000
# 75%                           3700.000000
# max                          20900.000000
#
#        Gemiddeld inkomen per inkomensontvanger :x 1 000 euro  \
# count                                       76612.000000
# mean                                           30.915328
# std                                             7.220430
# min                                             8.100000
# 25%                                            26.500000
# 50%                                            29.600000
# 75%                                            33.800000
# max                                           131.400000
#
#        Gemiddeld inkomen per inwoner :x 1 000 euro  \
# count                                 76942.000000
# mean                                     24.086262
# std                                       5.213102
# min                                       7.700000
# 25%                                      20.900000
# 50%                                      23.300000
# 75%                                      26.000000
# max                                      84.400000
#
#        40% personen met laagste inkomen:%  20% personen met hoogste inkomen:%  \
# count                        76612.000000                        76612.000000
# mean                            38.542419                           21.193523
# std                              7.140262                            8.671924
# min                             11.900000                            0.000000
# 25%                             34.100000                           15.100000
# 50%                             38.600000                           20.100000
# 75%                             42.700000                           26.300000
# max                             93.900000                           59.400000
#
#        Actieven 15-75 jaar:%  40% huishoudens met laagste inkomen:%  \
# count           76571.000000                           75207.000000
# mean               58.975119                              36.584299
# std                 7.222549                              14.212234
# min                 5.800000                               2.100000
# 25%                54.900000                              26.300000
# 50%                59.100000                              34.500000
# 75%                63.100000                              46.200000
# max                93.000000                              98.700000
#
#        20% huishoudens met hoogste inkomen:%  \
# count                           75207.000000
# mean                               21.845324
# std                                11.592519
# min                                 0.000000
# 25%                                12.800000
# 50%                                20.300000
# 75%                                28.900000
# max                                83.900000
#
#        Huishoudens met een laag inkomen:%  \
# count                        75106.000000
# mean                             8.860276
# std                              5.332850
# min                              0.000000
# 25%                              5.200000
# 50%                              7.300000
# 75%                             10.900000
# max                             89.600000
#
#        Huish. onder of rond sociaal minimum:%  Woningvoorraad:aantal  \
# count                            75106.000000           78295.000000
# mean                                 7.241689            1666.166511
# std                                  4.337651            1589.127102
# min                                  0.000000               0.000000
# 25%                                  4.300000             624.000000
# 50%                                  6.100000            1244.000000
# 75%                                  9.000000            2191.000000
# max                                 54.900000           14326.000000
#
#        Gemiddelde woningwaarde:x 1 000 euro  Percentage eengezinswoning:%  \
# count                          76429.000000                  77539.000000
# mean                             214.973636                     69.539213
# std                               85.268763                     26.896295
# min                               38.000000                      0.000000
# 25%                              161.000000                     56.000000
# 50%                              202.000000                     79.000000
# 75%                              248.000000                     90.000000
# max                             1523.000000                    100.000000
#
#        Percentage bewoond:%  Koopwoningen:%  In bezit woningcorporatie:%  \
# count          77539.000000    77508.000000                 77508.000000
# mean              95.151085       61.753871                    25.118581
# std                5.050284       18.499705                    17.594589
# min               13.000000        0.000000                     0.000000
# 25%               94.000000       50.000000                    13.000000
# 50%               96.000000       64.000000                    23.000000
# 75%               98.000000       75.000000                    35.000000
# max              100.000000      100.000000                   100.000000
#
#        In bezit overige verhuurders:%  Bouwjaar vanaf 2000:%  \
# count                    77508.000000           77539.000000
# mean                        12.015676              16.833916
# std                         10.204300              24.475404
# min                          0.000000               0.000000
# 25%                          5.000000               3.000000
# 50%                          9.000000               9.000000
# 75%                         15.000000              17.000000
# max                        100.000000             100.000000
#
#        Westers totaal:aantal  Niet-westers totaal:aantal  \
# count           78295.000000                78295.000000
# mean              364.503864                  494.162846
# std               412.450492                 1025.179572
# min                 0.000000                    0.000000
# 25%               105.000000                   55.000000
# 50%               235.000000                  175.000000
# 75%               475.000000                  455.000000
# max              3625.000000                11915.000000
#
#        Geboorte totaal:aantal  Sterfte totaal:aantal  \
# count            78295.000000           78295.000000
# mean                37.183856              30.472061
# std                 40.274695              39.980518
# min                  0.000000               0.000000
# 25%                 10.000000               5.000000
# 50%                 25.000000              20.000000
# 75%                 50.000000              40.000000
# max                315.000000             415.000000
#
#        Eenpersoonshuishoudens:aantal  Huishoudens zonder kinderen:aantal  \
# count                   78295.000000                        78295.000000
# mean                      646.001086                          475.811163
# std                       791.433620                          424.193455
# min                         0.000000                            0.000000
# 25%                       175.000000                          190.000000
# 50%                       400.000000                          370.000000
# 75%                       805.000000                          640.000000
# max                      6120.000000                         3660.000000
#
#        Huishoudens met kinderen:aantal  Gemiddelde huishoudensgrootte:aantal  \
# count                     78295.000000                          78157.000000
# mean                        561.280861                              2.242605
# std                         527.459940                              0.367731
# min                           0.000000                              1.000000
# 25%                         205.000000                              2.000000
# 50%                         420.000000                              2.300000
# 75%                         750.000000                              2.500000
# max                        4185.000000                              6.000000
#
#        Bevolkingsdichtheid:aantal inwoners per km²  Aantal inwoners:aantal  \
# count                                 77978.000000            78295.000000
# mean                                   4532.420644             3659.354876
# std                                    3470.120737             3305.581116
# min                                       1.000000                0.000000
# 25%                                    2069.000000             1415.000000
# 50%                                    4028.000000             2810.000000
# 75%                                    6184.000000             4910.000000
# max                                   24207.000000            27650.000000
#
#        Mannen:aantal  0 tot 15 jaar:aantal  15 tot 25 jaar:aantal  \
# count   78295.000000          78295.000000           78295.000000
# mean     1800.444728            622.363944             443.015327
# std      1611.407471            592.041555             448.455035
# min         0.000000              0.000000               0.000000
# 25%       700.000000            225.000000             155.000000
# 50%      1395.000000            455.000000             315.000000
# 75%      2415.000000            840.000000             570.000000
# max     12970.000000           4495.000000            3420.000000
#
#        25 tot 45 jaar:aantal  45 tot 65 jaar:aantal  65 jaar of ouder:aantal  \
# count           78295.000000           78295.000000             78295.000000
# mean              959.301041             996.036784               640.168402
# std               959.984250             891.520402               669.901633
# min                 0.000000               0.000000                 0.000000
# 25%               335.000000             395.000000               210.000000
# 50%               690.000000             760.000000               450.000000
# 75%              1250.000000            1330.000000               860.000000
# max              7205.000000            6590.000000              7635.000000
#
#        Ongehuwd:aantal  Gehuwd:aantal  Gescheiden:aantal  Verweduwd:aantal  \
# count     78295.000000   78295.000000       78295.000000      78295.000000
# mean       1766.152436    1424.627179         282.140750        188.400920
# std        1708.206641    1251.210154         305.668986        218.502849
# min           0.000000       0.000000           0.000000          0.000000
# 25%         635.000000     565.000000          95.000000         55.000000
# 50%        1300.000000    1100.000000         200.000000        125.000000
# 75%        2360.000000    1925.000000         370.000000        255.000000
# max       13230.000000    9835.000000        2835.000000       2385.000000
#
#        Indelingswijziging wijken en buurten:code  \
# count                               78295.000000
# mean                                    1.157596
# std                                     0.524521
# min                                     1.000000
# 25%                                     1.000000
# 50%                                     1.000000
# 75%                                     1.000000
# max                                     3.000000
#
#        Bedrijfsvestigingen totaal:aantal  \
# count                       78181.000000
# mean                          261.057290
# std                           267.828012
# min                             0.000000
# 25%                            95.000000
# 50%                           185.000000
# 75%                           345.000000
# max                          3215.000000
#
#        A Landbouw, bosbouw en visserij:aantal  \
# count                            76616.000000
# mean                                 4.648442
# std                                 12.084405
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  5.000000
# max                                255.000000
#
#        B-F Nijverheid en energie:aantal  G+I Handel en horeca:aantal  \
# count                      76616.000000                 76616.000000
# mean                          39.273389                    58.823222
# std                           40.395010                    72.112211
# min                            0.000000                     0.000000
# 25%                           15.000000                    15.000000
# 50%                           25.000000                    35.000000
# 75%                           50.000000                    70.000000
# max                          375.000000                  1090.000000
#
#        H+J Vervoer, informatie en communicatie:aantal  \
# count                                    76616.000000
# mean                                        22.998395
# std                                         26.168551
# min                                          0.000000
# 25%                                         10.000000
# 50%                                         15.000000
# 75%                                         30.000000
# max                                        340.000000
#
#        K-L Financiële diensten, onroerend goed:aantal  \
# count                                    76616.000000
# mean                                        27.015049
# std                                         31.827822
# min                                          0.000000
# 25%                                         10.000000
# 50%                                         20.000000
# 75%                                         35.000000
# max                                        420.000000
#
#        M-N Zakelijke dienstverlening:aantal  \
# count                          76616.000000
# mean                              75.653519
# std                               90.560181
# min                                0.000000
# 25%                               25.000000
# 50%                               50.000000
# 75%                               95.000000
# max                             1290.000000
#
#        R-U Cultuur, recreatie, overige diensten:aantal  Oppervlakte totaal:ha  \
# count                                     76616.000000           78295.000000
# mean                                         37.438786             187.497388
# std                                          41.049242             389.102160
# min                                           0.000000               2.000000
# 25%                                          15.000000              43.000000
# 50%                                          25.000000              84.000000
# 75%                                          45.000000             174.000000
# max                                         520.000000           13014.000000
#
#        Oppervlakte land:ha  Oppervlakte water:ha  \
# count         78295.000000          78295.000000
# mean            179.775235              7.724005
# std             378.047905             38.916181
# min               2.000000              0.000000
# 25%              41.000000              0.000000
# 50%              81.000000              1.000000
# 75%             168.000000              4.000000
# max           12822.000000           1199.000000
#
#        Afstand tot oprit hoofdverkeersweg:km  \
# count                           77941.000000
# mean                                1.754357
# std                                 1.177622
# min                                 0.100000
# 25%                                 1.000000
# 50%                                 1.600000
# 75%                                 2.200000
# max                                43.700000
#
#        Afstand tot treinstations totaal:km  \
# count                         77941.000000
# mean                              4.916373
# std                               5.487052
# min                               0.200000
# 25%                               1.600000
# 50%                               3.000000
# 75%                               6.200000
# max                              60.100000
#
#        Afstand tot belangrijk overstapstation:km
# count                               77941.000000
# mean                                   10.593113
# std                                     8.657049
# min                                     0.300000
# 25%                                     3.900000
# 50%                                     8.300000
# 75%                                    14.700000
# max                                    69.200000

# %% [markdown]
# suspicious columns:
# - tuinoppervlakte
# - autoplekken
# - bedrooms (this turned out to be benign)
# - bathroom.aparte toilet
# - lotsurface

# %%
# tuinoppervlakte
idx = houses[houses.tuinoppervlakte == 999].index
houses.loc[idx,'tuinoppervlakte'] = None

# autoplekken
idx = houses[houses.autoplekken == 99].index
houses.loc[idx,'autoplekken'] = None

# bathroom.apart toilet
idx = houses[houses['bathroom.aparte toilet'] == 9].index
houses.loc[idx,'bathroom.aparte toilet'] = None

# lotsurface
idx = houses[houses['lotsurface'] == 999999].index
houses.loc[idx,'lotsurface'] = None
idx = houses[houses['lotsurface'] == 99999].index
houses.loc[idx,'lotsurface'] = None

# %% [markdown]
# **Creating features from the startdate column**

# %%
add_datepart(houses, 'startdate') # creates features such as dayofweek, month, year, quarter, etc.

# %% [markdown]
# **Create features from the realtors dataset**

# %%
realtors = pd.read_csv('realtors.csv', encoding='latin-1')
realtors = realtors.drop(['house'],axis=1)
reviews = pd.read_csv('reviews.csv', encoding='latin-1')
review_mean = reviews.groupby('url')['Deskundigheid', 'Lokale marktkennis', 'Prijs/kwaliteit',
       'Service/begeleiding'].mean() # computes mean for all reviews grouped by realtor
review_mean.columns = review_mean.columns + '_mean'
review_std = reviews.groupby('url')[
    'Bereikbaarheid en communicatie','Deskundigheid', 'Lokale marktkennis', 'Prijs/kwaliteit','Service/begeleiding',
    'Onderhandeling en resultaat'
].std() # computes standard deviation for all reviews grouped by realtor
review_std.columns = review_std.columns + '_std'
realtors = pd.merge(realtors, review_mean, left_on='realtor', right_index=True)
realtors = pd.merge(realtors, review_std, left_on='realtor', right_index=True)

missing = houses[~houses.realtor.isin(realtors.realtor)].realtor.unique()
extra=np.array([[missing[i]] + [None for n in range(17)] for i in range(len(missing))])
realtors_extra = pd.DataFrame(data=extra, columns=realtors.columns)
realtors = realtors.append(realtors_extra)
realtors = realtors.set_index(np.arange(len(realtors)))

houses = pd.merge(houses, realtors, left_on='realtor', right_on='realtor')

# %% [markdown]
# **Convert all categorical features to the pandas 'cat' data type**

# %%
# This makes them easy to process by the random forest algorithm
train_cats(houses)

# %% [markdown]
# **Finally transform the target variable using np.log**

# %%
# The advantage of this is we found it to give more accurate predictions, the disadvantage is that those
# numbers will be less round than if left untransformed, meaning it won't be a "normal" house price, so to speak
houses.endprice = np.log(houses.endprice)

# %% [markdown]
# **Impute all missing values using the mean for numerical features and mode for categorical ones**

# %%
houses = houses.drop(['enddate'], axis=1)

# %%
X, y, nas = proc_df(houses, 'endprice')

# %% [markdown]
# **Pickle files for later**

# %%
pickle.dump(X,open('X.p','wb'))
pickle.dump(y,open('y.p','wb'))
pickle.dump(nas,open('nas.p','wb'))
pickle.dump(price_change_index,open('pci.p','wb'))

# %%
pickle.dump(houses, open('houses.p','wb'))
